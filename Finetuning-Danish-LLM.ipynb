# %% [markdown]
# # GPU stuff

# %%
import tensorflow as tf

# Get the GPU device name.
device_name = tf.test.gpu_device_name()

# The device name should look like the following:
if device_name == '/device:GPU:0':
    print('Found GPU at: {}'.format(device_name))
else:
    raise SystemError('GPU device not found')
# Out:
# Found GPU at: /device:GPU:0

# %%
import torch

# If there's a GPU available...
if torch.cuda.is_available():    

    # Tell PyTorch to use the GPU.    
    device = torch.device("cuda")

    print('There are %d GPU(s) available.' % torch.cuda.device_count())

    print('We will use the GPU:', torch.cuda.get_device_name(0))

# If not...
else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: Tesla K80

# %% [markdown]
# # Packages and imports

# %%
# !pip3 install torchmetrics==0.4.1
# !pip3 install transformers==4.8.2
# !pip3 install pytorch_lightning==1.3.8
# !pip3 install Levenshtein

import json
import pandas as pd
import numpy as np
import random
from pytorch_lightning.utilities.apply_func import move_data_to_device
import Levenshtein as Lev
from tqdm.auto import tqdm

# Rasmus imports
from typing import List
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.dataset import T_co
from transformers import AutoTokenizer, T5ForConditionalGeneration
# Out:
# Collecting torchmetrics==0.4.1
#   Downloading torchmetrics-0.4.1-py3-none-any.whl (234 kB)
#      |████████████████████████████████| 234 kB 5.3 MB/s
# Requirement already satisfied: torch>=1.3.1 in /usr/local/lib/python3.7/dist-packages (from torchmetrics==0.4.1) (1.10.0+cu111)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from torchmetrics==0.4.1) (1.19.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from torchmetrics==0.4.1) (21.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.3.1->torchmetrics==0.4.1) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->torchmetrics==0.4.1) (3.0.6)
# Installing collected packages: torchmetrics
# Successfully installed torchmetrics-0.4.1
# Collecting transformers==4.8.2
#   Downloading transformers-4.8.2-py3-none-any.whl (2.5 MB)
#      |████████████████████████████████| 2.5 MB 5.3 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.8.2) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.8.2) (2019.12.20)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.8.2) (4.8.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==4.8.2) (4.62.3)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 43.6 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==4.8.2) (21.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from transformers==4.8.2) (3.13)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 39.5 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.8.2) (3.4.0)
# Collecting huggingface-hub==0.0.12
#   Downloading huggingface_hub-0.0.12-py3-none-any.whl (37 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.8.2) (1.19.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface-hub==0.0.12->transformers==4.8.2) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==4.8.2) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.8.2) (3.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.8.2) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.8.2) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.8.2) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.8.2) (2.10)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.8.2) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.8.2) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.8.2) (1.15.0)
# Installing collected packages: tokenizers, sacremoses, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.0.12 sacremoses-0.0.46 tokenizers-0.10.3 transformers-4.8.2
# Collecting pytorch_lightning==1.3.8
#   Downloading pytorch_lightning-1.3.8-py3-none-any.whl (813 kB)
#      |████████████████████████████████| 813 kB 5.3 MB/s
# Requirement already satisfied: tensorboard!=2.5.0,>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning==1.3.8) (2.7.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning==1.3.8) (21.3)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning==1.3.8) (4.62.3)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning==1.3.8) (1.10.0+cu111)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning==1.3.8) (1.19.5)
# Requirement already satisfied: pillow!=8.3.0 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning==1.3.8) (7.1.2)
# Collecting future>=0.17.1
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 45.6 MB/s
# Collecting pyDeprecate==0.3.0
#   Downloading pyDeprecate-0.3.0-py3-none-any.whl (10 kB)
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2021.11.1-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 45.5 MB/s
# Collecting PyYAML<=5.4.1,>=5.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 49.5 MB/s
# Requirement already satisfied: torchmetrics>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning==1.3.8) (0.4.1)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 42.4 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning==1.3.8) (2.23.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=17.0->pytorch_lightning==1.3.8) (3.0.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.3.8) (1.35.0)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.3.8) (3.17.3)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.3.8) (1.0.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.3.8) (0.37.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.3.8) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.3.8) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.3.8) (3.3.6)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.3.8) (0.12.0)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.3.8) (1.42.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.3.8) (57.4.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.3.8) (1.8.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py>=0.4->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.3.8) (1.15.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.3.8) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.3.8) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.3.8) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.3.8) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.3.8) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.3.8) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.3.8) (3.10.0.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.3.8) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning==1.3.8) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning==1.3.8) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning==1.3.8) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning==1.3.8) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.3.8) (3.1.1)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.2.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (192 kB)
#      |████████████████████████████████| 192 kB 49.5 MB/s
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning==1.3.8) (2.0.8)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning==1.3.8) (21.2.0)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 53.9 MB/s
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.2.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (160 kB)
#      |████████████████████████████████| 160 kB 52.4 MB/s
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Building wheels for collected packages: future
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=f3841c922fb22caaa500cfcd195341812b74c9002e43449e8f6969057fe87b8d
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
# Successfully built future
# Installing collected packages: multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, fsspec, aiohttp, PyYAML, pyDeprecate, future, pytorch-lightning
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: future
#     Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
# Successfully installed PyYAML-5.4.1 aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 asynctest-0.13.0 frozenlist-1.2.0 fsspec-2021.11.1 future-0.18.2 multidict-5.2.0 pyDeprecate-0.3.0 pytorch-lightning-1.3.8 yarl-1.7.2
# Collecting Levenshtein
#   Downloading Levenshtein-0.16.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (110 kB)
#      |████████████████████████████████| 110 kB 5.1 MB/s
# Collecting rapidfuzz<1.9,>=1.8.2
#   Downloading rapidfuzz-1.8.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (854 kB)
#      |████████████████████████████████| 854 kB 32.5 MB/s
# Installing collected packages: rapidfuzz, Levenshtein
# Successfully installed Levenshtein-0.16.0 rapidfuzz-1.8.3

# %% [markdown]
# # Load Data

# %% [markdown]
# Mount drive to load files faster

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
class MultiPlexDataset(Dataset):

    def __init__(self,
                 path_to_files: List[str],
                 only_include_corrections: bool = False):
        """

        :param path_to_files: List of paths to the files with data
        :param only_include_corrections: Whether to only include samples where there are corrections
        """

        self.only_include_corrections = only_include_corrections
        self.dataset_counter = 0
        self.data = {}

        print("Loading data...")
        for path in path_to_files:
            with open(path, "r", encoding="utf-8") as f:
                data = f.read().split("\n")

            current_norm_words = []
            current_ref_words = []

            for line in data:
                if not line:
                    self.create_samples(current_norm_words, current_ref_words)
                    current_ref_words = []
                    current_norm_words = []
                else:
                    norm, ref = line.split("\t")
                    current_norm_words.append(norm)
                    current_ref_words.append(ref)

        print("Dataset initialized...")

    def create_samples(self, norms, refs):
        if norms and refs:
            for i, word in enumerate(norms):

                if self.only_include_corrections and word == refs[i]:
                    continue

                if i == 0:
                    sample_input = "<extra_id_0>" + word + "<extra_id_1> " + " ".join(norms[i + 1:])
                elif i == len(norms) - 1:
                    sample_input = " ".join(norms[:i]) + " <extra_id_0>" + word + "<extra_id_1>"
                else:
                    sample_input = " ".join(norms[:i]) + " <extra_id_0>" + word + "<extra_id_1> " + " ".join(
                        norms[i + 1:])

                self.data[self.dataset_counter] = {"input_sample": sample_input, "expected_output": refs[i]}
                self.dataset_counter += 1

    def __getitem__(self, index) -> T_co:
        return self.data[index]

    def __len__(self):
        return len(self.data.keys())


class CollateFunctor:
    def __init__(self, tokenizer, encoder_max_length=320, decoder_max_length=32):
        self.tokenizer = tokenizer
        self.encoder_max_length = encoder_max_length
        self.decoder_max_length = decoder_max_length

    def __call__(self, samples):
        inputs = list(map(lambda x: x["input_sample"], samples))

        inputs = self.tokenizer(
            inputs, padding=True, truncation=True, pad_to_multiple_of=8,
            max_length=self.encoder_max_length, return_attention_mask=True, return_tensors='pt'
        )

        outputs = list(map(lambda x: x["expected_output"], samples))

        outputs = self.tokenizer(
            outputs, padding=True, truncation=True, pad_to_multiple_of=8,
            max_length=self.decoder_max_length, return_attention_mask=True, return_tensors='pt'
        )

        batch = {
            "input_ids": inputs.input_ids,
            "attention_mask": inputs.attention_mask,
            "labels": outputs.input_ids,
            "decoder_attention_mask": outputs.attention_mask
        }
        batch["labels"][batch["labels"] == self.tokenizer.pad_token_id] = -100  # used to mask the loss in T5
        return batch

# %%
dataset = MultiPlexDataset(path_to_files=["/content/drive/MyDrive/text/noisy_danish_data.txt"], only_include_corrections=True)
# Out:
# Loading data...
# Dataset initialized...

# %% [markdown]
# # Train test split and shorten data

# %%
N = 36010
dataset_short = random.sample(dataset.data.items(), N)

# %%
input_samples = list(map(lambda x: x[1]["input_sample"], dataset_short))
expected_outputs = list(map(lambda x: x[1]["expected_output"], dataset_short))

# %%
pc = 0.1
from sklearn.model_selection import train_test_split
input_samples_train, input_samples_test, expected_outputs_train, expected_outputs_test = train_test_split(input_samples, expected_outputs, test_size=pc)

# %%
print("Total number of train inputs", len(input_samples_train))
print("Total number of train outputs", len(expected_outputs_train))
print("Total number of test inputs", len(input_samples_test))
print("Total number of test outputs", len(expected_outputs_test))
# Out:
# Total number of train inputs 32409
# Total number of train outputs 32409
# Total number of test inputs 3601
# Total number of test outputs 3601

# %% [markdown]
# # Baseline WER

# %%
def calculate_wer(s1, s2):
    b = set(s1.split() + s2.split())
    word2char = dict(zip(b, range(len(b))))
    w1 = [chr(word2char[w]) for w in s1.split()]
    w2 = [chr(word2char[w]) for w in s2.split()]
    return Lev.distance(''.join(w1), ''.join(w2))

# %%
total_wer_baseline = 0
for i, input in enumerate(input_samples_test):
  idx1 = input.find('<') + 12
  input = input[idx1:]
  idx2 = input.find('<')
  input = input[:idx2]
  
  wer_baseline =  calculate_wer(expected_outputs_test[i],input)
  total_wer_baseline= total_wer_baseline + wer_baseline

avg_err_baseline = total_wer_baseline/len(input_samples_test)

print("Baseline word error rate is", avg_err_baseline)
# Out:
# Baseline word error rate is 1.00944182171619

# %% [markdown]
# # Untrained MLN baseline

# %%
tokenizer = AutoTokenizer.from_pretrained("ufal/byt5-small-multilexnorm2021-da")
model = T5ForConditionalGeneration.from_pretrained("ufal/byt5-small-multilexnorm2021-da")
# Out:
# Downloading:   0%|          | 0.00/2.59k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/706 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.50k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.20G [00:00<?, ?B/s]

# %%
model.to(device)
# Out:
# T5ForConditionalGeneration(
#   (shared): Embedding(384, 1472)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(384, 1472)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1472, out_features=384, bias=False)
#               (k): Linear(in_features=1472, out_features=384, bias=False)
#               (v): Linear(in_features=1472, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=1472, bias=False)
#               (relative_attention_bias): Embedding(32, 6)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=1472, out_features=3584, bias=False)
#               (wi_1): Linear(in_features=1472, out_features=3584, bias=False)
#               (wo): Linear(in_features=3584, out_features=1472, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1472, out_features=384, bias=False)
#               (k): Linear(in_features=1472, out_features=384, bias=False)
#               (v): Linear(in_features=1472, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=1472, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=1472, out_features=3584, bias=False)
#               (wi_1): Linear(in_features=1472, out_features=3584, bias=False)
#               (wo): Linear(in_features=3584, out_features=1472, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (2): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1472, out_features=384, bias=False)
#               (k): Linear(in_features=1472, out_features=384, bias=False)
#               (v): Linear(in_features=1472, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=1472, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=1472, out_features=3584, bias=False)
#               (wi_1): Linear(in_features=1472, out_features=3584, bias=False)
#               (wo): Linear(in_features=3584, out_features=1472, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (3): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1472, out_features=384, bias=False)
#               (k): Linear(in_features=1472, out_features=384, bias=False)
#               (v): Linear(in_features=1472, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=1472, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=1472, out_features=3584, bias=False)
#               (wi_1): Linear(in_features=1472, out_features=3584, bias=False)
#               (wo): Linear(in_features=3584, out_features=1472, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (4): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1472, out_features=384, bias=False)
#               (k): Linear(in_features=1472, out_features=384, bias=False)
#               (v): Linear(in_features=1472, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=1472, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=1472, out_features=3584, bias=False)
#               (wi_1): Linear(in_features=1472, out_features=3584, bias=False)
#               (wo): Linear(in_features=3584, out_features=1472, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (5): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1472, out_features=384, bias=False)
#               (k): Linear(in_features=1472, out_features=384, bias=False)
#               (v): Linear(in_features=1472, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=1472, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=1472, out_features=3584, bias=False)
#               (wi_1): Linear(in_features=1472, out_features=3584, bias=False)
#               (wo): Linear(in_features=3584, out_features=1472, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (6): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1472, out_features=384, bias=False)
#               (k): Linear(in_features=1472, out_features=384, bias=False)
#               (v): Linear(in_features=1472, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=1472, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=1472, out_features=3584, bias=False)
#               (wi_1): Linear(in_features=1472, out_features=3584, bias=False)
#               (wo): Linear(in_features=3584, out_features=1472, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (7): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1472, out_features=384, bias=False)
#               (k): Linear(in_features=1472, out_features=384, bias=False)
#               (v): Linear(in_features=1472, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=1472, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=1472, out_features=3584, bias=False)
#               (wi_1): Linear(in_features=1472, out_features=3584, bias=False)
#               (wo): Linear(in_features=3584, out_features=1472, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (8): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1472, out_features=384, bias=False)
#               (k): Linear(in_features=1472, out_features=384, bias=False)
#               (v): Linear(in_features=1472, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=1472, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=1472, out_features=3584, bias=False)
#               (wi_1): Linear(in_features=1472, out_features=3584, bias=False)
#               (wo): Linear(in_features=3584, out_features=1472, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (9): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1472, out_features=384, bias=False)
#               (k): Linear(in_features=1472, out_features=384, bias=False)
#               (v): Linear(in_features=1472, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=1472, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=1472, out_features=3584, bias=False)
#               (wi_1): Linear(in_features=1472, out_features=3584, bias=False)
#               (wo): Linear(in_features=3584, out_features=1472, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (10): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1472, out_features=384, bias=False)
#               (k): Linear(in_features=1472, out_features=384, bias=False)
#               (v): Linear(in_features=1472, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=1472, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=1472, out_features=3584, bias=False)
#               (wi_1): Linear(in_features=1472, out_features=3584, bias=False)
#               (wo): Linear(in_features=3584, out_features=1472, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (11): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1472, out_features=384, bias=False)
#               (k): Linear(in_features=1472, out_features=384, bias=False)
#               (v): Linear(in_features=1472, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=1472, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=1472, out_features=3584, bias=False)
#               (wi_1): Linear(in_features=1472, out_features=3584, bias=False)
#               (wo): Linear(in_features=3584, out_features=1472, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): T5Stack(
#     (embed_tokens): Embedding(384, 1472)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1472, out_features=384, bias=False)
#               (k): Linear(in_features=1472, out_features=384, bias=False)
#               (v): Linear(in_features=1472, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=1472, bias=False)
#               (relative_attention_bias): Embedding(32, 6)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1472, out_features=384, bias=False)
#               (k): Linear(in_features=1472, out_features=384, bias=False)
#               (v): Linear(in_features=1472, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=1472, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=1472, out_features=3584, bias=False)
#               (wi_1): Linear(in_features=1472, out_features=3584, bias=False)
#               (wo): Linear(in_features=3584, out_features=1472, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1472, out_features=384, bias=False)
#               (k): Linear(in_features=1472, out_features=384, bias=False)
#               (v): Linear(in_features=1472, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=1472, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1472, out_features=384, bias=False)
#               (k): Linear(in_features=1472, out_features=384, bias=False)
#               (v): Linear(in_features=1472, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=1472, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=1472, out_features=3584, bias=False)
#               (wi_1): Linear(in_features=1472, out_features=3584, bias=False)
#               (wo): Linear(in_features=3584, out_features=1472, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (2): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1472, out_features=384, bias=False)
#               (k): Linear(in_features=1472, out_features=384, bias=False)
#               (v): Linear(in_features=1472, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=1472, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1472, out_features=384, bias=False)
#               (k): Linear(in_features=1472, out_features=384, bias=False)
#               (v): Linear(in_features=1472, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=1472, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=1472, out_features=3584, bias=False)
#               (wi_1): Linear(in_features=1472, out_features=3584, bias=False)
#               (wo): Linear(in_features=3584, out_features=1472, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (3): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1472, out_features=384, bias=False)
#               (k): Linear(in_features=1472, out_features=384, bias=False)
#               (v): Linear(in_features=1472, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=1472, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1472, out_features=384, bias=False)
#               (k): Linear(in_features=1472, out_features=384, bias=False)
#               (v): Linear(in_features=1472, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=1472, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=1472, out_features=3584, bias=False)
#               (wi_1): Linear(in_features=1472, out_features=3584, bias=False)
#               (wo): Linear(in_features=3584, out_features=1472, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=1472, out_features=384, bias=False)
# )

# %%
total_wer_untrained= 0
output_print=[]

progress_bar = tqdm(range(len(input_samples_test)))

model.eval()
for i, input in enumerate(input_samples_test):
  input_batch = tokenizer(input, padding=True, truncation=False, pad_to_multiple_of=8,
                        return_attention_mask=True, return_tensors='pt')
  input_batch = move_data_to_device(input_batch, device)
  output= model.generate(**input_batch)
  decoded_output = tokenizer.batch_decode(output, skip_special_tokens=True)
  decoded_output= " ".join(decoded_output)

  output_print.append(decoded_output)

  wer_untrained=  calculate_wer(expected_outputs_test[i],decoded_output)
  total_wer_untrained= total_wer_untrained +wer_untrained

  progress_bar.update(1)


avg_err_untrained= total_wer_untrained/len(input_samples_test)
output_untrained = output_print


print("Average word error rate(Untrained MLN) is", avg_err_untrained)
# Out:
#   0%|          | 0/3601 [00:00<?, ?it/s]
# Average word error rate(Untrained MLN) is 1.0011108025548459

# %%
 incorrect_predictions_untrained = len(expected_outputs_test) - len([i for i, j in zip(output_untrained, expected_outputs_test) if i == j])
 print('incorrect predictions: ', incorrect_predictions_untrained, ' out of ', len(expected_outputs_test))
# Out:
# incorrect predictions:  3571  out of  3601

# %% [markdown]
# # Trained MLN

# %%
class MultilexnormDataset(Dataset):
    def __init__(self, inputs, outputs):
        self.inputs = inputs
        self.outputs = outputs

    def __getitem__(self, index):
        return self.inputs[index], self.outputs[index]

    def __len__(self):
        return len(self.inputs)

# %%
class CollateFunctor:
    def __init__(self, tokenizer, encoder_max_length=320, decoder_max_length=32):
        self.tokenizer = tokenizer
        self.encoder_max_length = encoder_max_length
        self.decoder_max_length = decoder_max_length

    def __call__(self, samples):

        # should be list of input and list of output
        inputs, outputs = map(list, zip(*samples))

        inputs = self.tokenizer(
            inputs, padding=True, truncation=True, pad_to_multiple_of=8,
            max_length=self.encoder_max_length, return_attention_mask=True, return_tensors='pt'
        )

        outputs = self.tokenizer(
            outputs, padding=True, truncation=True, pad_to_multiple_of=8,
            max_length=self.decoder_max_length, return_attention_mask=True, return_tensors='pt'
        )

        batch = {
            "input_ids": inputs.input_ids,
            "attention_mask": inputs.attention_mask,
            "labels": outputs.input_ids,
            "decoder_attention_mask": outputs.attention_mask
        }
        batch["labels"][batch["labels"] == self.tokenizer.pad_token_id] = -100  # used to mask the loss in T5
        return batch

# %%
dataset_mln = MultilexnormDataset(input_samples_train, expected_outputs_train)

# %%
dataloader = DataLoader(dataset_mln, batch_size=4, collate_fn = CollateFunctor(tokenizer))

# %%
from transformers import get_scheduler,AdamW

optimizer = AdamW(model.parameters(), lr=5e-5)
num_epochs = 1
num_training_steps = num_epochs * len(dataloader)
lr_scheduler = get_scheduler(
    "linear",
    optimizer=optimizer,
    num_warmup_steps=0,
    num_training_steps=num_training_steps
)

# %%
from tqdm.auto import tqdm

progress_bar = tqdm(range(num_training_steps))
total_loss = 0

model.train()
for epoch in range(num_epochs):
    for i, batch in enumerate(dataloader):
      batch = move_data_to_device(batch, device)
      outputs = model(**batch)
      loss = outputs.loss
      total_loss = total_loss + loss.item()
      loss.backward()

      optimizer.step()
      lr_scheduler.step()
      optimizer.zero_grad()
      progress_bar.update(1)

print(total_loss/len(batch))
# Out:
#   0%|          | 0/8103 [00:00<?, ?it/s]
# 1060.5532449658494

# %%
print((total_loss/len(batch))/len(dataloader))
# Out:
# 0.13088402381412434

# %%
total_wer = 0


progress_bar = tqdm(range(len(input_samples_test)))
output_print=[]

model.eval()
for i, input in enumerate(input_samples_test):
  input_batch = tokenizer(input, padding=True, truncation=False, pad_to_multiple_of=8,
                        return_attention_mask=True, return_tensors='pt')
  input_batch = move_data_to_device(input_batch, device)
  output= model.generate(**input_batch)
  decoded_output = tokenizer.batch_decode(output, skip_special_tokens=True)
  decoded_output= " ".join(decoded_output)

  output_print.append(decoded_output)
  wer=  calculate_wer(expected_outputs_test[i],decoded_output)
  total_wer= total_wer +wer

  progress_bar.update(1)

output_trained = output_print
# Out:
#   0%|          | 0/3601 [00:00<?, ?it/s]

# %%
avg_err_trained= total_wer/len(input_samples_test)
print(avg_err_trained)
# Out:
# 0.34768119966675926

# %%
 incorrect_predictions_trained = len(expected_outputs_test) - len([i for i, j in zip(output_print, expected_outputs_test) if i == j])
 print('incorrect predictions: ', incorrect_predictions_trained, ' out of ', len(expected_outputs_test))
# Out:
# incorrect predictions:  1208  out of  3601

# %% [markdown]
# # Comparison

# %%
print("mean error (baseline):  ", avg_err_baseline)
print("mean error (untrained): ", avg_err_untrained)
print('mean error (trained):   ', avg_err_trained)
print('incorrect predictions (baseline):  ', 'all')
print('incorrect predictions (untrained): ', incorrect_predictions_untrained, ' out of ', len(expected_outputs_test))
print('incorrect predictions (trained):   ', incorrect_predictions_trained, ' out of ', len(expected_outputs_test))
# Out:
# mean error (baseline):   1.00944182171619
# mean error (untrained):  1.0011108025548459
# mean error (trained):    0.34768119966675926
# incorrect predictions (baseline):   all
# incorrect predictions (untrained):  3571  out of  3601
# incorrect predictions (trained):    1208  out of  3601

# %%
n = 50
idx = np.random.choice(np.arange(len(expected_outputs_test)), n, replace=False)
for i in range(n):
  print('input:              ', input_samples_test[idx[i]])
  print('expected output:    ', expected_outputs_test[idx[i]])
  print('output (untrained): ', output_untrained[idx[i]])
  print('output (trained):   ', output_trained[idx[i]])
  print('\n')
# Out:
# input:               skuret måler om ring tre gange to meter har krydsfiner <extra_id_0>vægge<extra_id_1> grus bund og et bliktag
# expected output:
# output (untrained):  vægge
# output (trained):
#
#
# input:               de to andre står pænt i kø på sengen <extra_id_0>i<extra_id_1> mands punktum
# expected output:     imens
# output (untrained):  i
# output (trained):    imands
#
#
# input:               desuden kan man lave top <extra_id_0>tekster<extra_id_1> og bund tekster indsætte grafik og beder udskrive kuverter flette
# expected output:
# output (untrained):  tekster
# output (trained):
#
#
# input:               det er jo tør være næsten <extra_id_0>hver<extra_id_1> dag
# expected output:     vejr
# output (untrained):  hver
# output (trained):    vejr
#
#
# input:               det er tanke bevægende at de i tredje klasse er <extra_id_0>motiveret<extra_id_1> for at læse men at de herefter taber interessen for læsning
# expected output:     motiverede
# output (untrained):  motiveret
# output (trained):    motiverede
#
#
# input:               allerede om eftermiddagen var der et voldsomt leben foran <extra_id_0>fodbold<extra_id_1> katedralen punktum
# expected output:     fodboldkatedralen
# output (untrained):  fodbold
# output (trained):    fodboldkatedralen
#
#
# input:               <extra_id_0>niogtyve<extra_id_1> tusind to hundrede og seks
# expected output:     niogfyrre
# output (untrained):  niogtyve
# output (trained):    niogfyrre
#
#
# input:               sammenlignet med den lidt større vil jeg vove at mene at denne her er <extra_id_0>fuld<extra_id_1> tilstrækkeligt
# expected output:     fuldt
# output (untrained):  fuld
# output (trained):    fuldt
#
#
# input:               <extra_id_0>afsendt<extra_id_1> de åbne dokumenter som email
# expected output:     afsend
# output (untrained):  afsendt
# output (trained):    afsend
#
#
# input:               det eneste komma der rører sig på vandet komma bortset fra en <extra_id_0>sjældent<extra_id_1> pram komma er bristende gas bobler fra flodens moder bund punktum
# expected output:     sjælden
# output (untrained):  sjældent
# output (trained):    sjælden
#
#
# input:               det fandtes ikke i <extra_id_0>barns<extra_id_1> udvalg
# expected output:     barens
# output (untrained):  barns
# output (trained):    barens
#
#
# input:               otte en to fire seks og tres ni hundrede og <extra_id_0>treogtredive<extra_id_1>
# expected output:     toogtredive
# output (untrained):  treogtredive
# output (trained):    toogtredive
#
#
# input:               for få dage siden var den ny et <extra_id_0>årige<extra_id_1> ekstra uddannelse for kommende gymnasielærere i pædagogik og sidefag omtrent på plads
# expected output:
# output (untrained):  årige
# output (trained):
#
#
# input:               det er <extra_id_0>et<extra_id_1> snarere alt det ind imellem komma som bliver til virkelighed punktum
# expected output:     snarere
# output (untrained):  et
# output (trained):
#
#
# input:               som <extra_id_0>tre<extra_id_1> årig indledte han en livlig og aktiv pensionisttilværelse
# expected output:     tres
# output (untrained):  tre
# output (trained):    tres
#
#
# input:               <extra_id_0>uoverensstemmelserne<extra_id_1> i fjor er givetvis en del af forklaringen på det skarpe tonefald
# expected output:     uoverenstemmelserne
# output (untrained):  uoverensstemmelsern
# output (trained):    uoverenstemmelserne
#
#
# input:               det er en utrolig arrogance <extra_id_0>fodbold<extra_id_1> organisationerne udviser over for almindelige mennesker
# expected output:     fodboldorganisationerne
# output (untrained):  fodbold
# output (trained):    fodboldorganisation
#
#
# input:               ni otte to otte <extra_id_0>fireogtyve<extra_id_1> syv hundrede og femten
# expected output:     fireogfyrre
# output (untrained):  fireogtyve
# output (trained):    fireogfyrre
#
#
# input:               to tre fem nul tyve to hundrede og <extra_id_0>syv<extra_id_1> ofir
# expected output:     syvogfirs
# output (untrained):  syv
# output (trained):    syvogfirs
#
#
# input:               nul otte nul fire to <extra_id_0>og<extra_id_1> tres et hundrede og fem
# expected output:
# output (untrained):  og
# output (trained):
#
#
# input:               så man op kunne man se sejlende <extra_id_0>så<extra_id_1> mørke vinger drejende og slingrende mod tusinde stjerner
# expected output:     som
# output (untrained):  så
# output (trained):    såmørke
#
#
# input:               lige nu er kunstnerne ved at lægge sidste hånd på de sidste kartoner og derefter er det så <extra_id_0>vævende<extra_id_1> der venter
# expected output:     vævene
# output (untrained):  vævende
# output (trained):    vævende
#
#
# input:               for få dage siden var den nye etårige ekstra <extra_id_0>uddannelse<extra_id_1> for kommende gymnasielærere i pædagogik og sidefag omtrent på plads
# expected output:
# output (untrained):  uddannelse
# output (trained):    ekstrauddannelse
#
#
# input:               ifølge den forskergruppe som har testet planten er midlet billigt og uden bivirkninger og det vil blive <extra_id_0>klar<extra_id_1> til brug om mindre end et år
# expected output:
# output (untrained):  klar
# output (trained):
#
#
# input:               <extra_id_0>afsendt<extra_id_1> de åbne dokumenter som email
# expected output:     afsend
# output (untrained):  afsendt
# output (trained):    afsend
#
#
# input:               <extra_id_0>åben<extra_id_1> adressebog
# expected output:     åbn
# output (untrained):  åben
# output (trained):    åbn
#
#
# input:               især bytte manien har været en stor del af <extra_id_0>spillet<extra_id_1> succes punktum
# expected output:     spillets
# output (untrained):  spillet
# output (trained):    spillets
#
#
# input:               vis au <extra_id_0>turisme<extra_id_1>
# expected output:
# output (untrained):  turisme
# output (trained):
#
#
# input:               tre ni otte to otte <extra_id_0>og<extra_id_1> tredive fem hundrede og fireogtyve
# expected output:
# output (untrained):  og
# output (trained):
#
#
# input:               byen var domineret af grå betonblokke og alenlange køer der ventede tålmodigt på de rustne bybusser der osede af <extra_id_0>elle<extra_id_1>
# expected output:     ælde
# output (untrained):  eller
# output (trained):    ælde
#
#
# input:               det er i det hele taget et meget livligere i et helt anderledes tæt trafikeret strøg end det jeg <extra_id_0>kommer<extra_id_1> fra
# expected output:     kom
# output (untrained):  kommer
# output (trained):    kommer
#
#
# input:               det er langt <extra_id_0>fra<extra_id_1> alt man holder af der er sundt
# expected output:
# output (untrained):  fra
# output (trained):
#
#
# input:               endelig kan den bruges over brand eller som trods natur dele stadig er en sjælden grøn <extra_id_0>sag<extra_id_1> i gryderne
# expected output:
# output (untrained):  sag
# output (trained):
#
#
# input:               åben venligst min adresse <extra_id_0>på<extra_id_1> nu
# expected output:
# output (untrained):  på
# output (trained):    på
#
#
# input:               samtidig <extra_id_0>er<extra_id_1> gruppen vist at industrien ikke har patent på at bestemme udviklingen på hele arbejdsmarkedet
# expected output:     har
# output (untrained):  er
# output (trained):    har
#
#
# input:               til søs om sommeren er der fine chancer for at se hvaler sæler og måske <extra_id_0>en<extra_id_1> dog en isbjørn eller valgres
# expected output:     endog
# output (untrained):  en
# output (trained):    endog
#
#
# input:               elementerne komma der er ganske lette komma består af fiber gips omgivet af stål rammer komma og kan <extra_id_0>bruges<extra_id_1> til såvel byggeri af enfamiliehuse og etageejendomme punktum
# expected output:     buges
# output (untrained):  bruges
# output (trained):    bruges
#
#
# input:               den nye lov gjorde det nemmere at gennemskue hvad de <extra_id_0>havde<extra_id_1> krav på
# expected output:     har
# output (untrained):  havde
# output (trained):    havde
#
#
# input:               toges tusind tre hundrede og <extra_id_0>treogtred<extra_id_1>
# expected output:     treoghalvtreds
# output (untrained):  treogtred
# output (trained):    toogtredive
#
#
# input:               han kom med sin mor <extra_id_0>trusler<extra_id_1> i et tvprogram i sidste uge
# expected output:     mordtrusler
# output (untrained):  trusler
# output (trained):
#
#
# input:               som <extra_id_0>tre<extra_id_1> årig endelig er han en livlig og aktiv pensionisttilværelse
# expected output:     tres
# output (untrained):  tre
# output (trained):    tres
#
#
# input:               en direkte telefonlinje skal være med til at advare mod de sundhedsskadelige konsekvenser ved at bruge dog <extra_id_0>penge<extra_id_1> punktum
# expected output:
# output (untrained):  penge
# output (trained):    penge
#
#
# input:               forsyn teksten <extra_id_0>er<extra_id_1> for nogle
# expected output:     med
# output (untrained):  er
# output (trained):    for
#
#
# input:               arrangerer ændringer med <extra_id_0>back<extra_id_1> space
# expected output:     backspace
# output (untrained):  back
# output (trained):    backspace
#
#
# input:               fjorten tusind ni hundrede og <extra_id_0>fire<extra_id_1> firs
# expected output:     fireogfirs
# output (untrained):  fire
# output (trained):    fireogfirs
#
#
# input:               afslut denne og vis med <extra_id_0>nu<extra_id_1>
# expected output:
# output (untrained):  nu
# output (trained):
#
#
# input:               to en otte en syv <extra_id_0>og<extra_id_1> halvfjerds et hundrede og en
# expected output:
# output (untrained):  og
# output (trained):
#
#
# input:               udskriv dokument til fax <extra_id_0>modtager<extra_id_1>
# expected output:
# output (untrained):  modtager
# output (trained):
#
#
# input:               fem otte fire fire <extra_id_0>ni<extra_id_1> og tredive fem hundrede og en
# expected output:     niogtredive
# output (untrained):  ni
# output (trained):    niogtredive
#
#
# input:               det er <extra_id_0>langt<extra_id_1> fra alt man holder af ter os undt
# expected output:     langtfra
# output (untrained):  langt
# output (trained):    langtfra

# %%
n = 50
idx = np.random.choice(np.arange(len(expected_outputs_test)), n, replace=False)
for i in range(n):
  print('input:              ', input_samples_test[idx[i]])
  print('expected output:    ', expected_outputs_test[idx[i]])
  print('output (untrained): ', output_untrained[idx[i]])
  print('output (trained):   ', output_trained[idx[i]])
  print('\n')
# Out:
# input:               han har vejen indsat skaffe sig <extra_id_0>et<extra_id_1> elevplads
# expected output:     en
# output (untrained):  et
# output (trained):    elevpladsen
#
#
# input:               byen var domineret af grå betonblokke og alenlange køer der ventede tålmodigt på de rustne bybusser der osede af <extra_id_0>elle<extra_id_1>
# expected output:     ælde
# output (untrained):  eller
# output (trained):    ælde
#
#
# input:               det er også på <extra_id_0>tyde<extra_id_1>
# expected output:     tide
# output (untrained):  tyde
# output (trained):    tydelse
#
#
# input:               de <extra_id_0>roede<extra_id_1> unge til at holde sig væk punktum
# expected output:     rådede
# output (untrained):  roede
# output (trained):    roede
#
#
# input:               det er menneskeligt at fejle og selv en <extra_id_0>gastronomer<extra_id_1> kan tage fejl
# expected output:     gastronom
# output (untrained):  gastronomer
# output (trained):
#
#
# input:               udskriv dokumentet til <extra_id_0>fax<extra_id_1> modtager
# expected output:     faxmodtager
# output (untrained):  fax
# output (trained):    faxmodtager
#
#
# input:               uret skal kun have skiftet <extra_id_0>batteri<extra_id_1> to gange om året punktum
# expected output:     batterier
# output (untrained):  batteri
# output (trained):    batteriet
#
#
# input:               vi kan ikke blive ved med <extra_id_0>at<extra_id_1> mødes på denne måde
# expected output:
# output (untrained):  at
# output (trained):    mødes
#
#
# input:               <extra_id_0>nioghalvfems<extra_id_1> tusind fem hundrede og tolv
# expected output:     nioghalvtreds
# output (untrained):  nioghalvfems
# output (trained):    nioghalvfjerds
#
#
# input:               tilslut forbindelsen og afsendt <extra_id_0>i<extra_id_1> mail
# expected output:     email
# output (untrained):  i
# output (trained):    email
#
#
# input:               det er altså en <extra_id_0>teater<extra_id_1> krig mellem en lessig og en ossi
# expected output:     teaterkrig
# output (untrained):  teater
# output (trained):    teaterkrig
#
#
# input:               skriv <extra_id_0>autorer<extra_id_1> summe af tex eller i regneark
# expected output:     autoresumé
# output (untrained):  autorer
# output (trained):    autoresumé
#
#
# input:               <extra_id_0>gentager<extra_id_1> første linie i dokumentet
# expected output:     gentag
# output (untrained):  gentager
# output (trained):    gentag
#
#
# input:               jeg hørte i en læge udsendelse at det er godt at give øjnene en dråbe amerikansk olie to gange <extra_id_0>dagligt<extra_id_1> hvis de føles generende tørre
# expected output:     daglig
# output (untrained):  dagligt
# output (trained):    daglig
#
#
# input:               uden sammenligning i øvrigt kan hunde være mindst <extra_id_0>lyse<extra_id_1> rædselsslagne som mennesker får i øvrigt ufarlige situationer
# expected output:     lige så
# output (untrained):  lyse
# output (trained):    lysrædselsslagne
#
#
# input:               alle er mellem <extra_id_0>tre<extra_id_1> og tyve og tredive år komma for det er den alders ramme komma uddannelsen sigter på punktum
# expected output:     treogtyve
# output (untrained):  tre
# output (trained):    treogtyve
#
#
# input:               flyet er nu blevet gennem <extra_id_0>tjekket<extra_id_1> og vi kan gøre klar til afgang om et øjeblik
# expected output:
# output (untrained):  tjekket
# output (trained):
#
#
# input:               hvorfor skulle de de udelukkes <extra_id_0>for<extra_id_1> denne ret spørgsmålstegn
# expected output:     fra
# output (untrained):  for
# output (trained):    fra
#
#
# input:               den tjener tyve procent af dagpengene hver gang en person tager <extra_id_0>sabbat<extra_id_1> orlov
# expected output:     sabbatorlov
# output (untrained):  sabbat
# output (trained):    sabbatorlovet
#
#
# input:               men selv om mine seneste ting har været skal vi sige lidt mere <extra_id_0>organiseret<extra_id_1> betragter jeg mig først og fremmest som en improvisator en solist
# expected output:     organiserede
# output (untrained):  organiseret
# output (trained):    organiserede
#
#
# input:               den ene udstilling var åben men den anden var netop <extra_id_0>i<extra_id_1> lukket
# expected output:     lukket
# output (untrained):  i
# output (trained):    lukket
#
#
# input:               han har vist sin <extra_id_0>taknemmelighed<extra_id_1> på anden måde punktum
# expected output:     taknemlighed
# output (untrained):  taknemmelighed
# output (trained):    taknemmelighed
#
#
# input:               bogen indeholder oprigtighed i roni menneske kendskab og en tendens til at gøre det <extra_id_0>lidt<extra_id_1> nar af befolkningens finere lag
# expected output:
# output (untrained):  lidt
# output (trained):    lidt
#
#
# input:               for få dage siden var den ny et årige <extra_id_0>ekstra<extra_id_1> uddannelse for kommende gymnasielærere i pædagogik og sidefag omtrent på plads
# expected output:
# output (untrained):  ekstra
# output (trained):
#
#
# input:               ni otte to otte <extra_id_0>fireogtyve<extra_id_1> syv hundrede og femten
# expected output:     fireogfyrre
# output (untrained):  fireogtyve
# output (trained):    fireogfyrre
#
#
# input:               afspil filen i <extra_id_0>ændrede<extra_id_1> format
# expected output:     ændret
# output (untrained):  ændrede
# output (trained):    ændr
#
#
# input:               men det vil både være besværligt at <extra_id_0>få<extra_id_1> dyrene hvis vi skal arbejde med to systemer
# expected output:
# output (untrained):  få
# output (trained):
#
#
# input:               virksomheden beskæftiger cirka et hundrede medarbejdere <extra_id_0>hvor<extra_id_1> er to tredjedele af ansat i produktionen
# expected output:     hvoraf
# output (untrained):  hvor
# output (trained):    hvoraf
#
#
# input:               og det vil så <extra_id_0>mænd<extra_id_1> ikke undre ham om han kommer i semifinalen
# expected output:
# output (untrained):  mænd
# output (trained):
#
#
# input:               tredive tusind tre hundrede og <extra_id_0>svogers<extra_id_1>
# expected output:     syvoghalvfjerds
# output (untrained):  svogers
# output (trained):    seksogtres
#
#
# input:               daglige arbejdsdag kan varieres med <extra_id_0>et<extra_id_1> kort frist
# expected output:     kort
# output (untrained):  et
# output (trained):    kort
#
#
# input:               men det behøver vi i <extra_id_0>økonomer<extra_id_1> ikke at tænke på
# expected output:
# output (untrained):  økonomer
# output (trained):
#
#
# input:               enogtyve tusind fire hundrede og <extra_id_0>fireogtyve<extra_id_1>
# expected output:     fireogfyrre
# output (untrained):  fireogtyve
# output (trained):    fireogfyrre
#
#
# input:               det går <extra_id_0>rigtig<extra_id_1> godt for vores patienter komma som får et godt liv efter indgrebet punktum
# expected output:     rigtigt
# output (untrained):  rigtig
# output (trained):    rigtigt
#
#
# input:               vis <extra_id_0>hjælpe<extra_id_1> liniel
# expected output:     hjælpelineal
# output (untrained):  hjælpe
# output (trained):    hjælpeliniel
#
#
# input:               overfør indkomne e <extra_id_0>mail<extra_id_1> til indbakken
# expected output:
# output (untrained):  mail
# output (trained):
#
#
# input:               sommerhusene er også en central brik i kommunernes <extra_id_0>turist<extra_id_1> politik
# expected output:     turistpolitik
# output (untrained):  turist
# output (trained):    turistpolitik
#
#
# input:               tilslut forbindelsen er afsendt <extra_id_0>i<extra_id_1> mail
# expected output:     email
# output (untrained):  i
# output (trained):    email
#
#
# input:               som navnet antyder er der tale om en anordning i en lang række af <extra_id_0>bærbar<extra_id_1> elektriske apparater
# expected output:     bærbare
# output (untrained):  bærbare
# output (trained):    bærbare
#
#
# input:               højt på en vinget hest hed bogen komma som <extra_id_0>beskæftiger<extra_id_1> sig med symboler og drømmes betydning i hans romaner punktum
# expected output:     beskæftigede
# output (untrained):  beskæftiger
# output (trained):    beskæftiger
#
#
# input:               men det vil være <extra_id_0>både<extra_id_1> besværligt og for dyrene hvis vi skal arbejde med to systemer
# expected output:     være
# output (untrained):  både
# output (trained):    både
#
#
# input:               man tager en menings mål i <extra_id_0>alvorlighed<extra_id_1> i firmaet
# expected output:     her
# output (untrained):  alvorlighed
# output (trained):    alvorligheden
#
#
# input:               direktøren komma der repræsenterer næsten et tusind dagligvareforretninger lige fra store varehuse til små kiosker komma er stærkt kritisk over for lukkelovens <extra_id_0>omsætnings<extra_id_1> grænse punktum
# expected output:     omsætningsgrænse
# output (untrained):  omsætnings
# output (trained):    omsætningsgrænse
#
#
# input:               det betyder ikke nødvendigvis at <extra_id_0>biografreklamer<extra_id_1> er bedre end tvreklamen men først og fremmest at publikum har haft en bedre oplevelse
# expected output:     biografreklamen
# output (untrained):  biografreklamer
# output (trained):    biografreklamen
#
#
# input:               ni en seks to fire <extra_id_0>og<extra_id_1> tres seks hundrede og seksten
# expected output:
# output (untrained):  og
# output (trained):
#
#
# input:               den kan opfattes som kommer <extra_id_0>cialis<extra_id_1> isk komma og i øvrigt mener jeg ikke komma at arkitektur komma og for den sags skyld komma kunst i det hele taget komma skal formidles punktum
# expected output:
# output (untrained):  cialisisk
# output (trained):
#
#
# input:               de små lygter som blandt andet har placeret på toilet skiltningen er udført i en <extra_id_0>magisk<extra_id_1> stil der passer godt til stemning og byggeri i øvrigt
# expected output:     maurisk
# output (untrained):  magisk
# output (trained):    magisk
#
#
# input:               fortryd udskriv til <extra_id_0>fax<extra_id_1> modtagere
# expected output:     faxmodtager
# output (untrained):  fax
# output (trained):    faxmodtager
#
#
# input:               den savner den opmærksomhed over for detaljen der måske som et trylleslag kunne gøre både <extra_id_0>menneske<extra_id_1> og stridigheder rigtig nærværende
# expected output:     mennesker
# output (untrained):  menneske
# output (trained):    menneskestridighede
#
#
# input:               udskriv dokument til fax <extra_id_0>modtagere<extra_id_1>
# expected output:
# output (untrained):  modtagere
# output (trained):

# %%
n = 50
idx = np.random.choice(np.arange(len(expected_outputs_test)), n, replace=False)
for i in range(n):
  print('input:              ', input_samples_test[idx[i]])
  print('expected output:    ', expected_outputs_test[idx[i]])
  print('output (untrained): ', output_untrained[idx[i]])
  print('output (trained):   ', output_trained[idx[i]])
  print('\n')
# Out:
# input:               vis <extra_id_0>hjælpe<extra_id_1> inat
# expected output:     hjælpelineal
# output (untrained):  hjælpe
# output (trained):    hjælpesnat
#
#
# input:               den gamle <extra_id_0>bronze<extra_id_1> statue foran rådhuset at pille ned lagt i en kiste med skumplast og befordret til hovedstaden
# expected output:     bronzestatue
# output (untrained):  bronze
# output (trained):    bronzestatue
#
#
# input:               fire ni seks otte <extra_id_0>otte<extra_id_1> og tyve to hundrede og sytten
# expected output:
# output (untrained):  otte
# output (trained):    otteogtyve
#
#
# input:               hun har ikke tænkt sig lige nu at lave flere detaljerede <extra_id_0>mindste<extra_id_1> krav til kommunernes ældrepleje børnepasning eller aktivering af bistandsmodtagere
# expected output:     mindstekrav
# output (untrained):  mindste
# output (trained):    ministerkrav
#
#
# input:               tre seks nul seks syv <extra_id_0>og<extra_id_1> halvfems et hundrede og sytten
# expected output:
# output (untrained):  og
# output (trained):
#
#
# input:               med disse penge har de <extra_id_0>kunne<extra_id_1> etablere sig som næringsdrivende i deres eget land
# expected output:     kunnet
# output (untrained):  kunne
# output (trained):    kunne
#
#
# input:               der er begyndt at komme nogle underlige pibe <extra_id_0>lyde<extra_id_1> fra bilens inde forhjul
# expected output:
# output (untrained):  lyde
# output (trained):
#
#
# input:               koncerterne nåede i sidste årti international berømmelse gennem et alsidigt sammensat program med deltagelse af kendte solister komma <extra_id_0>kam<extra_id_1> orkestre og kor fra alle kontinenter punktum
# expected output:     kammerorkestre
# output (untrained):  kam
# output (trained):    kamporkestre
#
#
# input:               de nye lærere derimod er meget <extra_id_0>engageret<extra_id_1> og stiller større krav
# expected output:     engagerede
# output (untrained):  engageret
# output (trained):    engagerede
#
#
# input:               <extra_id_0>vinderup<extra_id_1> plantage
# expected output:     vrenderup
# output (untrained):  Vinderup
# output (trained):    vinderup
#
#
# input:               det luner ikke ret meget men det sikrer at <extra_id_0>den<extra_id_1> nederste rosen ikke tørrer ud i hårde frost perioder
# expected output:     det
# output (untrained):  den
# output (trained):    denne
#
#
# input:               de implicerede parter skal <extra_id_0>indbyrdes<extra_id_1> til at deltage i møderne som observatører punktum
# expected output:     indbydes
# output (untrained):  indbyrdes
# output (trained):    indbyrdes
#
#
# input:               ud fra en solidarisk politik er der ikke en bestemt løsning der er den rejer <extra_id_0>det<extra_id_1>
# expected output:
# output (untrained):  det
# output (trained):    det
#
#
# input:               dette hjørne <extra_id_0>er<extra_id_1> dobbeltmoral hvor et lands øvrige sociale problemer får lov at vokse bare de gør det røgfrit lader vi ligge i denne omgang
# expected output:     af
# output (untrained):  er
# output (trained):    af
#
#
# input:               brug auto <extra_id_0>korrektur<extra_id_1> ved alle begyndelsesbogstaver
# expected output:
# output (untrained):  korrektur
# output (trained):
#
#
# input:               de mange nye gebyrer opfylder ikke helt bankernes hensigt om at <extra_id_0>adfærds<extra_id_1> regulere deres kunder punktum
# expected output:     adfærdsregulere
# output (untrained):  adfærds
# output (trained):    adfærdsregulere
#
#
# input:               vis hjælpe <extra_id_0>lineal<extra_id_1>
# expected output:
# output (untrained):  lineal
# output (trained):
#
#
# input:               selv det billigste papir <extra_id_0>leksikon<extra_id_1> koster nogle tusinde mens en cd kan fås for mellem tre hundrede og fem hundrede
# expected output:
# output (untrained):  leksikon
# output (trained):
#
#
# input:               de kan orientere dig om hvor meget du skal have i løn som <extra_id_0>voksen<extra_id_1> elev i det geografiske område for at du kan fuldføre uddannelsen
# expected output:     voksenelev
# output (untrained):  voksen
# output (trained):    voksenelev
#
#
# input:               men det er før set komma at professionelle komma der skal have en amatør makker komma ikke ligefrem er over <extra_id_0>motiveret<extra_id_1> punktum
# expected output:
# output (untrained):  motiveret
# output (trained):
#
#
# input:               ikke <extra_id_0>en<extra_id_1> føring havde belgieren taget undervejs
# expected output:     én
# output (untrained):  en
# output (trained):    en
#
#
# input:               samlingen her bekræfter til fulde hvad vi har i <extra_id_0>ventet<extra_id_1>
# expected output:     vente
# output (untrained):  ventet
# output (trained):
#
#
# input:               fremhæv nye adresser i distributions <extra_id_0>liste<extra_id_1>
# expected output:
# output (untrained):  liste
# output (trained):
#
#
# input:               det er helt urimeligt og det må høre op mener forbrugerombudsmanden der <extra_id_0>er<extra_id_1> klaget til branchen
# expected output:     har
# output (untrained):  er
# output (trained):    har
#
#
# input:               skuret måler omkring tre gange to meter har krydsfiner vægge <extra_id_0>grus<extra_id_1> bund og et bliktag
# expected output:
# output (untrained):  grus
# output (trained):
#
#
# input:               direktøren komma der repræsenterer næsten et tusind <extra_id_0>dagligvare<extra_id_1> forretninger lige fra store varehuse til små kiosker komma er stærkt kritisk over for lukkelovens omsætnings grænse punktum
# expected output:     dagligvareforretninger
# output (untrained):  dagligvare
# output (trained):    dagligvareforretnin
#
#
# input:               nu gider han ikke længere at <extra_id_0>have<extra_id_1> med musik at gøre overhovedet
# expected output:
# output (untrained):  have
# output (trained):
#
#
# input:               det er altså en <extra_id_0>teater<extra_id_1> krig mellem en ase og en ossi
# expected output:     teaterkrig
# output (untrained):  teater
# output (trained):    teaterkrig
#
#
# input:               men giver du mig ret i at det virkede som et reklamespot midt i en vejrudsigt men som <extra_id_0>ser<extra_id_1> forventer er neutral
# expected output:     seer
# output (untrained):  ser
# output (trained):    serieforventer
#
#
# input:               avisen sætter sig blot for at finde ud af om det også kan betale sig for den almindelige forbruger at tjekke <extra_id_0>varerne<extra_id_1> datomærkning
# expected output:     varernes
# output (untrained):  varerne
# output (trained):    varernes
#
#
# input:               <extra_id_0>afsendt<extra_id_1> de tre første breve
# expected output:     afsend
# output (untrained):  afsendt
# output (trained):    afsend
#
#
# input:               en <extra_id_0>miljø<extra_id_1> avis skal inspirere komma motivere og videregive erfaringer punktum
# expected output:     miljøavis
# output (untrained):  miljø
# output (trained):    miljøavis
#
#
# input:               min kommode kommer fra min mormor som <extra_id_0>vist<extra_id_1> nok har ejet den længere tilbage i familien
# expected output:     vistnok
# output (untrained):  vist
# output (trained):    vistnok
#
#
# input:               mødedeltagerne der er landenes miljø <extra_id_0>udviklings<extra_id_1> ministre og finansministre holder til tredje årlige møde her i maj
# expected output:     udviklingsministre
# output (untrained):  udviklings
# output (trained):
#
#
# input:               i år er <extra_id_0>overhæng<extra_id_1> fra tidlig overenskomster langt lavere punktum
# expected output:     overhænget
# output (untrained):  overhæng
# output (trained):    overhængene
#
#
# input:               <extra_id_0>fremhæve<extra_id_1> bogmærke
# expected output:     fremhæv
# output (untrained):  fremhæve
# output (trained):    fremhæv
#
#
# input:               fire to tre ni sek og <extra_id_0>firs<extra_id_1> et hundrede og syvogtyve
# expected output:
# output (untrained):  firs
# output (trained):
#
#
# input:               har man en vindues snige kan kan der føjes endnu en dimension til de <extra_id_0>nice<extra_id_1> kan udnyttes
# expected output:     nichen
# output (untrained):  nice
# output (trained):
#
#
# input:               skønt sommeren går på <extra_id_0>held<extra_id_1> er vejret lige nu til udendørsliv
# expected output:     hæld
# output (untrained):  held
# output (trained):    held
#
#
# input:               projektet er støttet med midler fra <extra_id_0>den<extra_id_1> danske kulturkredse og med udviklingsbistand
# expected output:     danske
# output (untrained):  den
# output (trained):    den
#
#
# input:               seks fem fire en treo <extra_id_0>firs<extra_id_1> ni hundrede og enogtyve
# expected output:
# output (untrained):  firs
# output (trained):
#
#
# input:               gem som <extra_id_0>tekst<extra_id_1> fil på diskette
# expected output:     tekstfil
# output (untrained):  tekst
# output (trained):    tekstfil
#
#
# input:               <extra_id_0>redigerer<extra_id_1> i data om fax modtager
# expected output:     rediger
# output (untrained):  redigerer
# output (trained):    rediger
#
#
# input:               <extra_id_0>nioghalvfems<extra_id_1> tusind fem hundrede og tolv
# expected output:     nioghalvtreds
# output (untrained):  nioghalvfems
# output (trained):    nioghalvfjerds
#
#
# input:               vi har det forspring at vores hold har været en <extra_id_0>takt<extra_id_1>
# expected output:
# output (untrained):  takt
# output (trained):
#
#
# input:               giv denne <extra_id_0>e<extra_id_1> post høj prioritet
# expected output:     epost
# output (untrained):  egentlige
# output (trained):    epost
#
#
# input:               <extra_id_0>kog<extra_id_1> ned er der imidlertid kun tre kandidater der slås om de to pladser i finalen
# expected output:     kogt
# output (untrained):  Kog
# output (trained):    kogt
#
#
# input:               uret skal kun have skiftet <extra_id_0>batteri<extra_id_1> to gange om året punktum
# expected output:     batterier
# output (untrained):  batteri
# output (trained):    batteriet
#
#
# input:               i en buket plastic blomst <extra_id_0>der<extra_id_1> syner et kvinde hovedet frem
# expected output:
# output (untrained):  der
# output (trained):
#
#
# input:               hvis ja komma hvorfor har han så ikke gjort det for mange år siden <extra_id_0>punktum<extra_id_1> spørgsmålstegn
# expected output:     spørgsmålstegn
# output (untrained):  punktum
# output (trained):    punktum

# %%
n = 50
idx = np.random.choice(np.arange(len(expected_outputs_test)), n, replace=False)
for i in range(n):
  print('input:              ', input_samples_test[idx[i]])
  print('expected output:    ', expected_outputs_test[idx[i]])
  print('output (untrained): ', output_untrained[idx[i]])
  print('output (trained):   ', output_trained[idx[i]])
  print('\n')
# Out:
# input:               har man en <extra_id_0>vindues<extra_id_1> niche kan der for os endnu en dimension til den ethan kan udnyttes
# expected output:     vinduesniche
# output (untrained):  vindues
# output (trained):    vinduesniche
#
#
# input:               indsæt <extra_id_0>s<extra_id_1> bet i det markerede felt
# expected output:     tabel
# output (untrained):  så
# output (trained):    søbet
#
#
# input:               <extra_id_0>ved<extra_id_1> hvad du skal bruge den fodnote til
# expected output:     vid
# output (untrained):  ved
# output (trained):    vi
#
#
# input:               det er altså en <extra_id_0>teater<extra_id_1> krig mellem en ase og en ossi
# expected output:     teaterkrig
# output (untrained):  teater
# output (trained):    teaterkrig
#
#
# input:               byen var domineret af grå betonblokke <extra_id_0>alen<extra_id_1> lange køer der ventede tålmodigt på de rustne bybusser der osede af elle
# expected output:     og
# output (untrained):  alen
# output (trained):
#
#
# input:               hans opfattelse af sin rolle som <extra_id_0>far<extra_id_1> er ganske enkelt punktum
# expected output:     fader
# output (untrained):  far
# output (trained):    farver
#
#
# input:               hvis det var gået skævt dengang var hans karriere <extra_id_0>kørte<extra_id_1> af sporet fra begyndelsen
# expected output:     kørt
# output (untrained):  kørte
# output (trained):    kørt
#
#
# input:               vi tillader <extra_id_0>altså<extra_id_1> konstatere at dette faktum nok også gælder voksne
# expected output:     os at
# output (untrained):  altså
# output (trained):    altså
#
#
# input:               det er <extra_id_0>et<extra_id_1> snarere alt det ind imellem komma som bliver til virkelighed punktum
# expected output:     snarere
# output (untrained):  et
# output (trained):
#
#
# input:               de kom gående med deres bambus <extra_id_0>stinger<extra_id_1>
# expected output:
# output (untrained):  stinger
# output (trained):
#
#
# input:               tre en ni fem <extra_id_0>tre<extra_id_1> og tres et hundrede
# expected output:     treogtres
# output (untrained):  tre
# output (trained):    treogtres
#
#
# input:               sagen har yderligere det principielle indhold om en klar lovovertrædelse kan gøres straffri af en offentlig myndigheds <extra_id_0>kludret<extra_id_1> med tingene
# expected output:     kludren
# output (untrained):  kludret
# output (trained):    kludren
#
#
# input:               <extra_id_0>hvis<extra_id_1> autoritet er dette dokument
# expected output:     vis
# output (untrained):  hvis
# output (trained):    hvis
#
#
# input:               selv de billigste <extra_id_0>papir<extra_id_1> leksikon koster nogle tusinde mens en cd kan fås for mellem tre hundrede og fem hundrede
# expected output:     papirleksikon
# output (untrained):  papir
# output (trained):    papirleksikoner
#
#
# input:               dette hjørne er dobbelt moral hvor landets øvrige sociale problemer får lov at vokse og <extra_id_0>at<extra_id_1> de gør det røgfrit lader vi ligge i denne omgang
# expected output:
# output (untrained):  at
# output (trained):    at
#
#
# input:               med farver komma plakater komma hatte komma pjecer komma bøger komma ja komma så mænd også de obligatoriske <extra_id_0>engang<extra_id_1> sejlere punktum
# expected output:     engangslightere
# output (untrained):  engang
# output (trained):    engangsejlere
#
#
# input:               de kom gående med deres bambus <extra_id_0>stænger<extra_id_1>
# expected output:
# output (untrained):  stænger
# output (trained):
#
#
# input:               hvordan <extra_id_0>værdi<extra_id_1> fastsætter man skader på historiske bygninger som følge af den sure regn som kraftværkerne bærer en stor del af ansvaret for
# expected output:     værdifastsætter
# output (untrained):  værdi
# output (trained):    værdifastsætter
#
#
# input:               <extra_id_0>log<extra_id_1> computeren
# expected output:     luk
# output (untrained):  log
# output (trained):    log
#
#
# input:               <extra_id_0>afsendt<extra_id_1> denne email til alle kunder
# expected output:     afsend
# output (untrained):  afsendt
# output (trained):    afsend
#
#
# input:               find word <extra_id_0>filer<extra_id_1>
# expected output:
# output (untrained):  filer
# output (trained):
#
#
# input:               to otte otte seks nioghalvfems et hundrede og otte <extra_id_0>fyrre<extra_id_1>
# expected output:
# output (untrained):  fyrre
# output (trained):
#
#
# input:               <extra_id_0>afbrud<extra_id_1> handlingen og gå til funktions linien
# expected output:     afbryd
# output (untrained):  afbrud
# output (trained):    afbryd
#
#
# input:               marker skærmbillede dokument <extra_id_0>oversigt<extra_id_1> nummer to
# expected output:     dokumentoversigt
# output (untrained):  oversigt
# output (trained):
#
#
# input:               læg den indkommende e <extra_id_0>post<extra_id_1> i indbakken
# expected output:     epost
# output (untrained):  post
# output (trained):
#
#
# input:               det er <extra_id_0>langt<extra_id_1> fra alt man holder af deres sundt
# expected output:     langtfra
# output (untrained):  langt
# output (trained):    langtfra
#
#
# input:               find <extra_id_0>word<extra_id_1> filer
# expected output:     wordfiler
# output (untrained):  word
# output (trained):    wordfiler
#
#
# input:               det <extra_id_0>er<extra_id_1> almindelige danske
# expected output:     alm
# output (untrained):  er
# output (trained):    almindelig
#
#
# input:               parret har som regel altid et <extra_id_0>kunstneriske<extra_id_1> indslag med komma når de drager på store komma officielle besøg i udlandet punktum
# expected output:
# output (untrained):  kunstneriske
# output (trained):    kunstnerisk
#
#
# input:               flyet er nu <extra_id_0>er<extra_id_1> blevet gennem tjekket og vi kan gøre klar til afgang om et øjeblik
# expected output:     blevet
# output (untrained):  er
# output (trained):    blevet
#
#
# input:               han satte <extra_id_0>sig<extra_id_1> vel dansk som nordisk rekord
# expected output:     såvel
# output (untrained):  sig
# output (trained):    såvel
#
#
# input:               han havde <extra_id_0>søgt<extra_id_1> at tanken om at det er solen der i centrum er universet
# expected output:     søsat
# output (untrained):  søgt
# output (trained):    søgt
#
#
# input:               jaco supermarkeder a <extra_id_0>s<extra_id_1>
# expected output:
# output (untrained):  s
# output (trained):
#
#
# input:               <extra_id_0>bilen<extra_id_1> blev ført frem i en pressemeddelelse og netop den fremgangsmåde faldt dem for brystet
# expected output:     kritikken
# output (untrained):  bilen
# output (trained):    bilen
#
#
# input:               fremmes <extra_id_0>cykel<extra_id_1> shortsene og den forcerede fores forelskelse
# expected output:     med
# output (untrained):  cykel
# output (trained):    cykelshortsene
#
#
# input:               det er menneskeligt at fejle og selv en <extra_id_0>gastronomer<extra_id_1> kan tage fejl
# expected output:     gastronom
# output (untrained):  gastronomer
# output (trained):
#
#
# input:               skal man vælge mellem sandheden og <extra_id_0>savnet<extra_id_1> så savnet altid sandheden fastslår de to brødre
# expected output:     sagnet
# output (untrained):  savnet
# output (trained):    sagnet
#
#
# input:               tilslut forbindelsen og afsendt i <extra_id_0>mail<extra_id_1>
# expected output:
# output (untrained):  mail
# output (trained):
#
#
# input:               i modsat fald vil den være en af nære oplevelser der nok er og forbliver og <extra_id_0>fjerne<extra_id_1>
# expected output:
# output (untrained):  fjerne
# output (trained):    fjerner
#
#
# input:               jeg hørte i en læge udsendelse at det er godt at give øjnene en dråbe amerikansk olie to gange <extra_id_0>dagligt<extra_id_1> hvis de fører generende tørre
# expected output:     daglig
# output (untrained):  dagligt
# output (trained):    daglig
#
#
# input:               det kan bruges og bliver flittigt brugt af nordmændene <extra_id_0>rådet<extra_id_1> rundt
# expected output:     året
# output (untrained):  rådet
# output (trained):    rådet
#
#
# input:               en leverandør og kursister i <extra_id_0>adressebogen<extra_id_1>
# expected output:     adressebog
# output (untrained):  adressebogen
# output (trained):    adressebogen
#
#
# input:               fire fem tre nul ni og fyrre seks hundrede og <extra_id_0>femoghalvfjerds<extra_id_1>
# expected output:     femoghalvtreds
# output (untrained):  femoghalvfjerds
# output (trained):    femoghalvtreds
#
#
# input:               men giver du mig ret i at det virkede som et reklamespot midt i en vejrudsigt men som <extra_id_0>ser<extra_id_1> forventer er neutral
# expected output:     seer
# output (untrained):  ser
# output (trained):    serieforventer
#
#
# input:               problemet er ikke den påpeget risiko for lov <extra_id_0>artede<extra_id_1> serne forældelse som i givet fald ville sætte en stopper for undersøgelserne
# expected output:
# output (untrained):  artede
# output (trained):
#
#
# input:               når karen <extra_id_0>e<extra_id_1> blokeres opstår de enorme hævelser der har givet sygdommen dens navn
# expected output:
# output (untrained):  e
# output (trained):
#
#
# input:               aforismer og charmerende paradokser flød i en u over <extra_id_0>adelige<extra_id_1> strøm for hans aldrig udtørrende kilde af lun kløgt punktum
# expected output:
# output (untrained):  adelige
# output (trained):
#
#
# input:               hvis der er brug for dem i junglen er <extra_id_0>det<extra_id_1> i junglen
# expected output:     de
# output (untrained):  det
# output (trained):    de
#
#
# input:               to hundrede og <extra_id_0>eno<extra_id_1> tredive
# expected output:     enogtredive
# output (untrained):  en
# output (trained):    enogtredive
#
#
# input:               koncerterne nåede i sidste årti international berømmelse gennem et alsidigt sammensat program med deltagelse af kendte solister komma kammer <extra_id_0>orkestre<extra_id_1> og kor fra alle kontinenter punktum
# expected output:
# output (untrained):  orkestre
# output (trained):

# %%
n = 50
idx = np.random.choice(np.arange(len(expected_outputs_test)), n, replace=False)
for i in range(n):
  print('input:              ', input_samples_test[idx[i]])
  print('expected output:    ', expected_outputs_test[idx[i]])
  print('output (untrained): ', output_untrained[idx[i]])
  print('output (trained):   ', output_trained[idx[i]])
  print('\n')
# Out:
# input:               københavnerne skal ikke nøjes med at sætte deres skriftlige aftryk på kommunens fremtid på en stemme <extra_id_0>så<extra_id_1> hvert fjerde år punktum
# expected output:
# output (untrained):  så
# output (trained):    så
#
#
# input:               slet kommandoer og <extra_id_0>skrevet<extra_id_1> på dansk
# expected output:
# output (untrained):  skrevet
# output (trained):    skrevet
#
#
# input:               men lykkelig det bliver du ikke siger den <extra_id_0>tredive<extra_id_1> årige læge der ikke selv har det alt for godt med livskvaliteten i disse dage
# expected output:     trediveårige
# output (untrained):  tredive
# output (trained):    trediveårige
#
#
# input:               de spiller på mandag ud med et tilbud komma der ifølge selskabet selv gør det billigere end nogen <extra_id_0>sinde<extra_id_1> tidligere at tale i mobiltelefon punktum
# expected output:
# output (untrained):  sinde
# output (trained):
#
#
# input:               evolutionen vil helt sikkert bringe os tilbage til det <extra_id_0>kollektive<extra_id_1> ubevidste mentale økosystem
# expected output:     kollektivt
# output (untrained):  kollektive
# output (trained):    kollektive
#
#
# input:               fire to fire tre to og <extra_id_0>halvfjerds<extra_id_1> ni hundrede og seksten
# expected output:
# output (untrained):  halvfjerds
# output (trained):
#
#
# input:               de vil i den kommende tid fremlægge udspil til omfattende saneringer af dagpengesystemet og <extra_id_0>social<extra_id_1> systemet
# expected output:     socialsystemet
# output (untrained):  social
# output (trained):    socialsystemet
#
#
# input:               selv om man går ind for traditioner er der vel <extra_id_0>grænse<extra_id_1>
# expected output:     grænser
# output (untrained):  grænse
# output (trained):    grænser
#
#
# input:               de implicerede parter skal <extra_id_0>indbyrdes<extra_id_1> til at deltage i møderne som observatører punktum
# expected output:     indbydes
# output (untrained):  indbyrdes
# output (trained):    indbyrdes
#
#
# input:               syv seks syv <extra_id_0>syv<extra_id_1> syv og halvfjerds otte hundrede og fireogtyve
# expected output:
# output (untrained):  syv
# output (trained):
#
#
# input:               hvis vi får styrket tekniker <extra_id_0>uddannelserne<extra_id_1> betyder det at de kan tage et job som i dag bliver udført af ingeniører
# expected output:
# output (untrained):  uddannelserne
# output (trained):
#
#
# input:               kritikken blev <extra_id_0>jeg<extra_id_1> ført frem i en pressemeddelelse og netop den fremgangsmåde faldt dem for brystet
# expected output:     ført
# output (untrained):  jeg
# output (trained):
#
#
# input:               <extra_id_0>svogers<extra_id_1> tusind seks hundrede og en
# expected output:     syvoghalvtreds
# output (untrained):  svogers
# output (trained):    seksogtres
#
#
# input:               hvis vi får styrket tekniker uddannelserne betyder det at de kan <extra_id_0>sætte<extra_id_1> job som i dag bliver udført af ingeniører
# expected output:     tage
# output (untrained):  sætte
# output (trained):    sætte
#
#
# input:               avisernes forandring påvirker ikke bare bog anmeldelsens form men også <extra_id_0>den<extra_id_1> attituder og dens retoriske greb
# expected output:     dens
# output (untrained):  den
# output (trained):    denne
#
#
# input:               soldaterne skulle blot rengøre vognen og skifte et dæk for at få <extra_id_0>dem<extra_id_1> til at køre
# expected output:     den
# output (untrained):  dem
# output (trained):    den
#
#
# input:               angiv et <extra_id_0>tidspunkt<extra_id_1> for automatisk afsendelse
# expected output:
# output (untrained):  tidspunkt
# output (trained):
#
#
# input:               for få dage siden var den ny etårige <extra_id_0>ekstra<extra_id_1> uddannelse for den kommende gymnasielærere i pædagogik og sidefag omtrent på plads
# expected output:     ekstrauddannelse
# output (untrained):  ekstra
# output (trained):    ekstrauddannelse
#
#
# input:               samtidig kan man så opleve den poesi der er hos vikingerne altså i skatte <extra_id_0>digtene<extra_id_1>
# expected output:
# output (untrained):  digtene
# output (trained):
#
#
# input:               <extra_id_0>afsendt<extra_id_1> de tre første breve
# expected output:     afsend
# output (untrained):  afsendt
# output (trained):    afsend
#
#
# input:               prisen skal jo holdes nede når det er <extra_id_0>hjemmebrugere<extra_id_1> man vil gå efter
# expected output:     hjemmebrugerne
# output (untrained):  hjemmebrugere
# output (trained):    hjemmebruger
#
#
# input:               fem fem fem ni ti et hundrede og <extra_id_0>halvtreds<extra_id_1>
# expected output:     treoghalvtreds
# output (untrained):  halvtreds
# output (trained):
#
#
# input:               tilføje <extra_id_0>autoriseret<extra_id_1> for markerede afsnit
# expected output:     autoresumé
# output (untrained):  autoriseret
# output (trained):    autoresumé
#
#
# input:               forsyn teksten <extra_id_0>er<extra_id_1> for nogle
# expected output:     med
# output (untrained):  er
# output (trained):    for
#
#
# input:               jeg hørte i en <extra_id_0>læge<extra_id_1> udsendelse og det er godt at give øjnene en dråbe amerikansk skole to gange dagligt hvis det føltes generende tørre
# expected output:     lægeudsendelse
# output (untrained):  læge
# output (trained):    lægeudsendelse
#
#
# input:               har man en <extra_id_0>vindues<extra_id_1> niche kan der for os endnu en dimension til den nichen kan udnyttes
# expected output:     vinduesniche
# output (untrained):  vindues
# output (trained):    vinduesniche
#
#
# input:               de konstruerede den første danske serie komma som kunne hamle op med de amerikanske og engelske situations <extra_id_0>komedier<extra_id_1> punktum
# expected output:
# output (untrained):  komedier
# output (trained):
#
#
# input:               brugte både kan være mindst lige så <extra_id_0>fortale<extra_id_1> i køb som brugte biler
# expected output:     fatale
# output (untrained):  fortale
# output (trained):    fortalte
#
#
# input:               treogtredive tusind ni hundrede og otte <extra_id_0>gres<extra_id_1>
# expected output:
# output (untrained):  gres
# output (trained):
#
#
# input:               den anarkistiske holdning er et centralt punkt i punkerne stil og det er den kvalitet der har haft størst indflydelse på den almindelige <extra_id_0>måde<extra_id_1>
# expected output:     mode
# output (untrained):  måde
# output (trained):    måde
#
#
# input:               vælg <extra_id_0>auto<extra_id_1> korrektur i menu
# expected output:     autokorrektur
# output (untrained):  auto
# output (trained):    autokorrektur
#
#
# input:               sagen har yderligere de principiel og indhold om en klar lovovertrædelse kan gøres straffri af en offentlig myndigheds <extra_id_0>kluden<extra_id_1> med tingene
# expected output:     kludren
# output (untrained):  kluden
# output (trained):    kludren
#
#
# input:               p r <extra_id_0>e<extra_id_1> p a r e r e d e
# expected output:     æ
# output (untrained):
# output (trained):    æ
#
#
# input:               nej men vi har det system at vi er flere lærere om en første <extra_id_0>klasse<extra_id_1> og vi prøver at holde to gennemgående lærere på hvert klassetrin
# expected output:
# output (untrained):  klasse
# output (trained):
#
#
# input:               rådet vil ifølge forslaget få en væsentlig større magt end nu hvor de fungere som fødselshjælper for ellers <extra_id_0>udstødte<extra_id_1> teater projekter
# expected output:     ustøttede
# output (untrained):  udstødte
# output (trained):    udstødte
#
#
# input:               udskriv dokument til fax <extra_id_0>modtagere<extra_id_1>
# expected output:
# output (untrained):  modtagere
# output (trained):
#
#
# input:               <extra_id_0>videresendt<extra_id_1> den markerede epost
# expected output:     videresend
# output (untrained):  videresendt
# output (trained):    videresend
#
#
# input:               <extra_id_0>inde<extra_id_1> format
# expected output:     ændr
# output (untrained):  inde
# output (trained):    ændr
#
#
# input:               pladeselskaberne er nødt til at sænke prisen efter det enorme korridor <extra_id_0>arbejde<extra_id_1> de har udført for at få afgiften væk
# expected output:
# output (untrained):  arbejde
# output (trained):
#
#
# input:               der er begyndt at komme nogle underlige pibe <extra_id_0>lyde<extra_id_1> fra bilens inde forhjul
# expected output:
# output (untrained):  lyde
# output (trained):
#
#
# input:               hun mener komma <extra_id_0>at<extra_id_1> det er godt for de unge at arbejde komma så de lærer hvordan det er at komme ud i det virkelige liv punktum
# expected output:     det
# output (untrained):  at
# output (trained):    det
#
#
# input:               de små lygter som blandt andet er placeret på toilet <extra_id_0>skiltningen<extra_id_1> er udført i en maurisk stil der passer godt til stemning og byggeri i øvrigt
# expected output:
# output (untrained):  skiltningen
# output (trained):
#
#
# input:               <extra_id_0>set<extra_id_1> linnet
# expected output:     said
# output (untrained):  set
# output (trained):    se
#
#
# input:               det betyder ikke nødvendigvis at <extra_id_0>biografreklamer<extra_id_1> er bedre end tvreklamen men først og fremmest at publikum har haft en bedre oplevelse
# expected output:     biografreklamen
# output (untrained):  biografreklamer
# output (trained):    biografreklamen
#
#
# input:               som navnet antyder er der tale om en <extra_id_0>anmodning<extra_id_1> i en lang række af bærbar elektriske apparater
# expected output:     anordning
# output (untrained):  anmodning
# output (trained):    anmodning
#
#
# input:               form massen med en paletkniv komma så toppen <extra_id_0>spidse<extra_id_1> slet punktum
# expected output:     spidses
# output (untrained):  spidse
# output (trained):    spidses
#
#
# input:               koncerterne nåede i sidste årti international berømmelse gennem et alsidigt sammensat program med deltagelse <extra_id_0>er<extra_id_1> kendte solister komma kammerorkester og kor fra alle kontinenter punktum
# expected output:     af
# output (untrained):  er
# output (trained):    af
#
#
# input:               <extra_id_0>afsendt<extra_id_1> de åbne dokumenter som email
# expected output:     afsend
# output (untrained):  afsendt
# output (trained):    afsend
#
#
# input:               i en række bøger giver det et råt billede af nutidens store <extra_id_0>byer<extra_id_1>
# expected output:
# output (untrained):  byer
# output (trained):    byer
#
#
# input:               den hurtige udvikling af materiellet kræver at top sejler <extra_id_0>skifte<extra_id_1> grej hvert år
# expected output:     skifter
# output (untrained):  skifte
# output (trained):    skifter

# %%
n = 50
idx = np.random.choice(np.arange(len(expected_outputs_test)), n, replace=False)
for i in range(n):
  print('input:              ', input_samples_test[idx[i]])
  print('expected output:    ', expected_outputs_test[idx[i]])
  print('output (untrained): ', output_untrained[idx[i]])
  print('output (trained):   ', output_trained[idx[i]])
  print('\n')
# Out:
# input:               det vil næppe få det danske samfund eller <extra_id_0>nogle<extra_id_1> af de andre lande der overholder reglerne til at bryde sammen
# expected output:     nogen
# output (untrained):  nogle
# output (trained):    nogen
#
#
# input:               det giver en utilfredsstillende konkurrence <extra_id_0>for<extra_id_1> bredning siger han
# expected output:
# output (untrained):  for
# output (trained):    for
#
#
# input:               der skal også mere end man vi <extra_id_0>er<extra_id_1> i stand til at holde punktum
# expected output:     være
# output (untrained):  er
# output (trained):    er
#
#
# input:               der er et udvalg <extra_id_0>arbejde<extra_id_1> med disse ting og hvis det er et udvalg siger at der skal bruges flere penge vil vi se på sagen
# expected output:     der arbejder
# output (untrained):  arbejde
# output (trained):
#
#
# input:               han var iført en mørk <extra_id_0>neglen<extra_id_1> jakke med et rødligt mærke ved venstre bryst forvaskede lyseblå kogebog er med huller på benene og hvide kondisko
# expected output:     nylonjakke
# output (untrained):  neglen
# output (trained):    neglenjakke
#
#
# input:               tilføjer denne tekst i <extra_id_0>auto<extra_id_1> tekst
# expected output:     autotekst
# output (untrained):  auto
# output (trained):    autotekst
#
#
# input:               to fem fire syv to og <extra_id_0>halvfjerds<extra_id_1> ni hundrede og treogtre
# expected output:
# output (untrained):  halvfjerds
# output (trained):
#
#
# input:               det svæver <extra_id_0>op<extra_id_1> i natte himlen så man frygter at et hvert øjeblik kunne falde ned
# expected output:     oppe
# output (untrained):  op
# output (trained):    oppe
#
#
# input:               syv fem to seks treo <extra_id_0>firs<extra_id_1> otte hundrede og nioghalvfems
# expected output:
# output (untrained):  firs
# output (trained):
#
#
# input:               ni syv otte seks ni og <extra_id_0>fyrre<extra_id_1> ni hundrede og seksten
# expected output:
# output (untrained):  fyrre
# output (trained):
#
#
# input:               fem fem fem ni ti et hundrede og <extra_id_0>halvtreds<extra_id_1>
# expected output:     treoghalvtreds
# output (untrained):  halvtreds
# output (trained):
#
#
# input:               kamstrup <extra_id_0>a<extra_id_1> s
# expected output:     as
# output (untrained):  å
# output (trained):    as
#
#
# input:               bogen indeholder oprigtighed i <extra_id_0>roni<extra_id_1> menneske kendskab og en tendens til at gøre lidt nar af befolkningens finere lag
# expected output:
# output (untrained):  roni
# output (trained):
#
#
# input:               det er altså en teater krig mellem en <extra_id_0>væg<extra_id_1> og en osi
# expected output:     wessie
# output (untrained):  væg
# output (trained):    vægt
#
#
# input:               i <extra_id_0>først<extra_id_1> kommende weekend kan man opleve de islandske hestes fem gangarter her under tønden som de racerene islandske heste er enige om at kunne
# expected output:     førstkommende
# output (untrained):  først
# output (trained):    førstkommende
#
#
# input:               desuden kan man lave top tekster og <extra_id_0>bund<extra_id_1> tekster indsætte grafik og billeder udskrive kuverter flette
# expected output:     bundtekster
# output (untrained):  bund
# output (trained):    bundtekster
#
#
# input:               afslut auto <extra_id_0>funktion<extra_id_1>
# expected output:
# output (untrained):  funktion
# output (trained):
#
#
# input:               erstat <extra_id_0>de<extra_id_1> markerede ord med følgende
# expected output:     det
# output (untrained):  de
# output (trained):    det
#
#
# input:               de vestlige landes <extra_id_0>interesser<extra_id_1> er i begrænset
# expected output:     interesse
# output (untrained):  interesser
# output (trained):    interesser
#
#
# input:               erstat fejl <extra_id_0>dato<extra_id_1> med korrekt dato
# expected output:
# output (untrained):  dato
# output (trained):
#
#
# input:               find hjælpe <extra_id_0>minu<extra_id_1>
# expected output:
# output (untrained):  minu
# output (trained):
#
#
# input:               jeg har mere end en gang både mundtligt og skriftligt måtte dementere at udtale mig <extra_id_0>så<extra_id_1> ledes
# expected output:     således
# output (untrained):  så
# output (trained):    således
#
#
# input:               de vil i den kommende tid fremlægge udspil til omfattende saneringer af dagpengesystemet og social <extra_id_0>systemet<extra_id_1>
# expected output:
# output (untrained):  systemet
# output (trained):
#
#
# input:               <extra_id_0>fireogtyve<extra_id_1> tusind ni hundrede og enogtyve
# expected output:     fireogfyrre
# output (untrained):  fireogtyve
# output (trained):    fireogfyrre
#
#
# input:               da nat dykning sætter store krav til planlægningen bruger vi ventetiden inden solen går ned til at gennemgå <extra_id_0>håndtegn<extra_id_1> ler og andre praktiske foranstaltninger
# expected output:     håndsignaler
# output (untrained):  håndtegn
# output (trained):    håndtegnelser
#
#
# input:               de kommercielle <extra_id_0>tvstationer<extra_id_1> varer er sere
# expected output:     tvstationers
# output (untrained):  tvstationer
# output (trained):    tvstationers
#
#
# input:               <extra_id_0>annullerer<extra_id_1> formen for de nederste celler
# expected output:     annullér
# output (untrained):  annullerer
# output (trained):    annullér
#
#
# input:               tilføj auto <extra_id_0>resume<extra_id_1> for alle celler
# expected output:
# output (untrained):  resume
# output (trained):
#
#
# input:               selv det billigste papir leksikon koster nogle tusinde mens en set <extra_id_0>i<extra_id_1> kan fås for mellem tre hundrede og fem hundrede
# expected output:
# output (untrained):  i
# output (trained):
#
#
# input:               vi lever i et samfund der er <extra_id_0>et<extra_id_1> voldsomt forvandling
# expected output:     i
# output (untrained):  et
# output (trained):
#
#
# input:               han mener at miseren skyldes den manglende <extra_id_0>ideal<extra_id_1> dannelse i samfundsændringe
# expected output:     idealdannelse
# output (untrained):  ideal
# output (trained):    idealdannelse
#
#
# input:               fem fem fire to en og <extra_id_0>fyrre<extra_id_1> tre hundrede og fireogtyve
# expected output:
# output (untrained):  fyrre
# output (trained):
#
#
# input:               der skal også være tid til <extra_id_0>sneboldkamp<extra_id_1> hule bygning inden deres lege og spil
# expected output:     sneboldkampe
# output (untrained):  sneboldkamp
# output (trained):    sneboldkampe
#
#
# input:               for få dage siden var den ny <extra_id_0>et<extra_id_1> årige ekstra uddannelse for kommende gymnasielærere i pædagogik og sidefag omtrent på plads
# expected output:     etårige
# output (untrained):  et
# output (trained):    etårige
#
#
# input:               i en buket plastic blomster syner et kvinde <extra_id_0>hoved<extra_id_1> frem
# expected output:
# output (untrained):  hoved
# output (trained):
#
#
# input:               vi er et dansk produkt og det er et faktum vores modpart ikke skal <extra_id_0>opfattes<extra_id_1> som en svaghed
# expected output:     opfatte
# output (untrained):  opfattes
# output (trained):    opfatte
#
#
# input:               dertil kom han behovet for en grundlæggende ændring af <extra_id_0>bevilling<extra_id_1> praksis så pengene i højere grad følger patienterne
# expected output:     bevillingspraksis
# output (untrained):  bevilling
# output (trained):    bevillingspraksis
#
#
# input:               de spiller på mandag ud med et tilbud komma der ifølge selskabet selv gør det billigere end <extra_id_0>nogen<extra_id_1> sinde tidligere at tale i mobiltelefon punktum
# expected output:     nogensinde
# output (untrained):  nogen
# output (trained):    nogensinde
#
#
# input:               nul seks ni seks to ofir syv hundrede og <extra_id_0>treogtredive<extra_id_1>
# expected output:     toogtredive
# output (untrained):  treogtredive
# output (trained):    toogtredive
#
#
# input:               de kan orientere dig om hvor meget du skal have en løn som <extra_id_0>voksen<extra_id_1> elev i det geografiske område for at du kan fuldføre uddannelsen
# expected output:     voksenelev
# output (untrained):  voksen
# output (trained):    voksenelev
#
#
# input:               det er jo tør være næsten <extra_id_0>hver<extra_id_1> dag
# expected output:     vejr
# output (untrained):  hver
# output (trained):    vejr
#
#
# input:               arrangerer ændringer med back <extra_id_0>spage<extra_id_1>
# expected output:
# output (untrained):  spage
# output (trained):
#
#
# input:               det var <extra_id_0>ikke<extra_id_1> noget vi skulle
# expected output:     jo ikke
# output (untrained):  ikke
# output (trained):    noget
#
#
# input:               vi har generelt kontrol over de farligste <extra_id_0>bakterie<extra_id_1> typer herhjemme og de kan stadig slås ihjel med den gammeldags og penicillin
# expected output:     bakterietyper
# output (untrained):  bakterie
# output (trained):    bakterietyper
#
#
# input:               det er for <extra_id_0>de<extra_id_1> arbejdere og ofte møder allerede klokken syv altså en time før de fleste skoler begynder
# expected output:
# output (untrained):  de
# output (trained):
#
#
# input:               jeg hørte i en læge udsendelse at det er godt at give øjnene en dråbe amerikansk olie to gange dagligt hvis det <extra_id_0>føltes<extra_id_1> generende tørre
# expected output:     føles
# output (untrained):  føltes
# output (trained):    føles
#
#
# input:               det vil tørre <extra_id_0>være<extra_id_1> næsten hver dag
# expected output:     tørvejr
# output (untrained):  være
# output (trained):
#
#
# input:               den dyre <extra_id_0>se<extra_id_1> er ikke bygget endnu punktum
# expected output:
# output (untrained):  se
# output (trained):
#
#
# input:               lod <extra_id_0>ld<extra_id_1> lod
# expected output:     lod
# output (untrained):  lød
# output (trained):    ld
#
#
# input:               når man lærer at spille klaver komma spiller man ikke kun stykker i stigende svares <extra_id_0>grad<extra_id_1> punktum
# expected output:
# output (untrained):  grad
# output (trained):

# %%
n = 50
idx = np.random.choice(np.arange(len(expected_outputs_test)), n, replace=False)
for i in range(n):
  print('input:              ', input_samples_test[idx[i]])
  print('expected output:    ', expected_outputs_test[idx[i]])
  print('output (untrained): ', output_untrained[idx[i]])
  print('output (trained):   ', output_trained[idx[i]])
  print('\n')
# Out:
# input:               seks fire syv en syv <extra_id_0>og<extra_id_1> tres seks hundrede og syvogtyve
# expected output:
# output (untrained):  og
# output (trained):
#
#
# input:               det er en utrolig arrogance <extra_id_0>fodbold<extra_id_1> organisationerne udviser over for almindelige mennesker
# expected output:     fodboldorganisationerne
# output (untrained):  fodbold
# output (trained):    fodboldorganisation
#
#
# input:               kan man leve af <extra_id_0>en<extra_id_1> lille galleri
# expected output:     et
# output (untrained):  en
# output (trained):    en
#
#
# input:               jeg tror oven <extra_id_0>i<extra_id_1> købet at den er sund
# expected output:
# output (untrained):  i
# output (trained):
#
#
# input:               da nat <extra_id_0>dykning<extra_id_1> sætter store krav til planlægning bruger vi ventetiden inden solen går ned til at gennemgå hånd signaler og andre praktiske foranstaltninger
# expected output:
# output (untrained):  dykning
# output (trained):
#
#
# input:               de svenske erfaringer med en lovgivning der er langt <extra_id_0>strenge<extra_id_1> og taler klart imod det
# expected output:     strengere
# output (untrained):  strenge
# output (trained):
#
#
# input:               jeg fatter ikke komma at de overhovedet <extra_id_0>ikke<extra_id_1> gider køre punktum
# expected output:     gider
# output (untrained):  ikke
# output (trained):    ikke
#
#
# input:               har man en vindues <extra_id_0>niche<extra_id_1> kan der føjes endnu en dimension til da nichen kan udnyttes
# expected output:
# output (untrained):  niche
# output (trained):
#
#
# input:               <extra_id_0>bonny<extra_id_1> kring
# expected output:     bonnie
# output (untrained):  Bonny
# output (trained):    bonny
#
#
# input:               det er <extra_id_0>vigtigt<extra_id_1> at tilbyde svenske børn med end for eksempel at have et godt skolebibliotek
# expected output:     vigtigere
# output (untrained):  vigtigt
# output (trained):    vigtigere
#
#
# input:               hvis vi får styrket <extra_id_0>tekniker<extra_id_1> uddannelserne betyder det at de kan tage job som i dag bliver udført af ingeniører
# expected output:     teknikeruddannelserne
# output (untrained):  tekniker
# output (trained):    teknikeruddannelser
#
#
# input:               pas på du ikke slår over <extra_id_0>hovedet<extra_id_1> punktum
# expected output:
# output (untrained):  hovedet
# output (trained):
#
#
# input:               for få år siden var der stor diskussion om hvilke maskiner der egentlig vil blive afspilning <extra_id_0>apparater<extra_id_1> for multimedie
# expected output:
# output (untrained):  apparater
# output (trained):
#
#
# input:               med farver komma plakater komma hatte komma pjecer komma bøger komma ja komma så mænd også de obligatoriske <extra_id_0>engang<extra_id_1> sejlere punktum
# expected output:     engangslightere
# output (untrained):  engang
# output (trained):    engangsejlere
#
#
# input:               fjorten tusind og tog <extra_id_0>tres<extra_id_1>
# expected output:
# output (untrained):  tres
# output (trained):
#
#
# input:               <extra_id_0>redigerer<extra_id_1> seneste handling
# expected output:     rediger
# output (untrained):  redigerer
# output (trained):    rediger
#
#
# input:               anvendt de markerede bogmærker som navigations <extra_id_0>mærker<extra_id_1>
# expected output:
# output (untrained):  mærker
# output (trained):
#
#
# input:               <extra_id_0>gentager<extra_id_1> første linie i dokumentet
# expected output:     gentag
# output (untrained):  gentager
# output (trained):    gentag
#
#
# input:               fisken er en særdeles lækker ferskvands <extra_id_0>fisk<extra_id_1> som man desværre møder for sjældent på spisekortet
# expected output:
# output (untrained):  fisk
# output (trained):
#
#
# input:               marker skærmbillede dokument <extra_id_0>oversigt<extra_id_1> nummer to
# expected output:     dokumentoversigt
# output (untrained):  oversigt
# output (trained):
#
#
# input:               interessen for hestesport nedarves i generationer og holder man samtidig øje med hestens blod linier kommer der en kontinuitet i sporten <extra_id_0>med<extra_id_1> næppe se andre steder
# expected output:     man
# output (untrained):  med
# output (trained):    men
#
#
# input:               hvis der er brug for dem i junglen er <extra_id_0>det<extra_id_1> i junglen
# expected output:     de
# output (untrained):  det
# output (trained):    de
#
#
# input:               flyet nu bliver gennem <extra_id_0>tjekkede<extra_id_1> vi kan gøre klar til afgang om et øjeblik
# expected output:     og
# output (untrained):  tjekkede
# output (trained):
#
#
# input:               dermed afspejler genren også sin egen indre opbygning og i sin funktion for middel <extra_id_0>se<extra_id_1> medier ing af modsætninger punktum
# expected output:     til
# output (untrained):  se
# output (trained):
#
#
# input:               dette burde vi <extra_id_0>have<extra_id_1> været vist når man nu har sat sig for at demonstrere designprocesser
# expected output:
# output (untrained):  have
# output (trained):    være
#
#
# input:               vi <extra_id_0>vil<extra_id_1> også have givet dem en video punktum
# expected output:     ville
# output (untrained):  vil
# output (trained):    vil
#
#
# input:               han lover at komme endnu højere på podiet <extra_id_0>i<extra_id_1> næste år
# expected output:     næste
# output (untrained):  i
# output (trained):    næste
#
#
# input:               <extra_id_0>afsendt<extra_id_1> det første dokument som email
# expected output:     afsend
# output (untrained):  afsendt
# output (trained):    afsend
#
#
# input:               vælg auto <extra_id_0>korrektur<extra_id_1> i menu
# expected output:
# output (untrained):  korrektur
# output (trained):
#
#
# input:               hans arbejde rummer en række holdninger ellers <extra_id_0>vil<extra_id_1> det ikke rigtigt interesserer os
# expected output:     ville
# output (untrained):  vil
# output (trained):    vil
#
#
# input:               ifølge den forskergruppe som har testet planten er middel billigt og uden bivirkninger og det vil blive <extra_id_0>klar<extra_id_1> til brug og mindre end et år
# expected output:
# output (untrained):  klar
# output (trained):
#
#
# input:               vi er et dansk produkt og det er et faktum vores modpart ikke skal <extra_id_0>omfatte<extra_id_1> som en svaghed
# expected output:     opfatte
# output (untrained):  omfatte
# output (trained):    omfatte
#
#
# input:               brug ikke auto <extra_id_0>tekst<extra_id_1> i de markerede afsnit
# expected output:
# output (untrained):  tekst
# output (trained):
#
#
# input:               otte ni nul seks to <extra_id_0>og<extra_id_1> fyrre tre hundrede og fireogtyve
# expected output:
# output (untrained):  og
# output (trained):
#
#
# input:               ni fem fire fire tre og <extra_id_0>fyrre<extra_id_1> fem hundrede og halvfems
# expected output:
# output (untrained):  fyrre
# output (trained):
#
#
# input:               brug <extra_id_0>back<extra_id_1> space
# expected output:     backspace
# output (untrained):  back
# output (trained):    backspace
#
#
# input:               slet bagud med <extra_id_0>back<extra_id_1> space
# expected output:     backspace
# output (untrained):  back
# output (trained):    backspace
#
#
# input:               fem nul tre ni otte og <extra_id_0>fyrre<extra_id_1> syv hundrede og halvfjerds
# expected output:
# output (untrained):  fyrre
# output (trained):
#
#
# input:               det eneste område hvor strøm <extra_id_0>svigtet<extra_id_1> fik følgevirkninger frem til i går var postomdelingen
# expected output:
# output (untrained):  svigtet
# output (trained):
#
#
# input:               teleoperatører skal altså have lov til <extra_id_0>at<extra_id_1> efter lør et infra struktur på tværs af landet
# expected output:
# output (untrained):  at
# output (trained):    efterløre
#
#
# input:               skuret måler omkring tre gange to meter har <extra_id_0>krydsfiner<extra_id_1> vægge grus bund og et bliktag
# expected output:     krydsfinervægge
# output (untrained):  krydsfiner
# output (trained):    krydsfinervægge
#
#
# input:               fem nul tre to <extra_id_0>en<extra_id_1> og fyrre ni hundrede og treogtre
# expected output:     enogfyrre
# output (untrained):  en
# output (trained):    enogfyrre
#
#
# input:               marker dette afsnit at <extra_id_0>flytte<extra_id_1> til start
# expected output:     flyt
# output (untrained):  flytte
# output (trained):    flyt
#
#
# input:               toyota danmark a <extra_id_0>s<extra_id_1>
# expected output:
# output (untrained):  s
# output (trained):
#
#
# input:               <extra_id_0>god<extra_id_1> til næste linie i dokumentet
# expected output:     gå
# output (untrained):  god
# output (trained):    god
#
#
# input:               <extra_id_0>åben<extra_id_1> effekter og vis grafiske muligheder
# expected output:     åbn
# output (untrained):  åben
# output (trained):    åbn
#
#
# input:               giv <extra_id_0>billede<extra_id_1> de valgte effekter
# expected output:     billedet
# output (untrained):  billede
# output (trained):    billedet
#
#
# input:               direktøren komma der repræsenterer næsten et tusind dagligvare forretninger lige fra store varehuse til små kiosker komma er stærkt kritisk over for lukkelovens omsætnings <extra_id_0>grænse<extra_id_1> punktum
# expected output:
# output (untrained):  grænse
# output (trained):
#
#
# input:               da <extra_id_0>nat<extra_id_1> dykning sætter store krav til planlægning bruger vi ventetiden inden solen går ned til at gennemgå hånd signaler og andre praktiske foranstaltninger
# expected output:     natdykning
# output (untrained):  nat
# output (trained):    natdykning
#
#
# input:               det konfronterer sagsbehandlerne med de aktuelle problemer i familien og fører i sidste ende til <extra_id_0>tvangs<extra_id_1> værelse siger han
# expected output:     tvangsfjernelse
# output (untrained):  tvangs
# output (trained):    tvangsværelse

# %%
n = 50
idx = np.random.choice(np.arange(len(expected_outputs_test)), n, replace=False)
for i in range(n):
  print('input:              ', input_samples_test[idx[i]])
  print('expected output:    ', expected_outputs_test[idx[i]])
  print('output (untrained): ', output_untrained[idx[i]])
  print('output (trained):   ', output_trained[idx[i]])
  print('\n')
# Out:
# input:               det er langt <extra_id_0>fra<extra_id_1> alt man holder af der er sundt
# expected output:
# output (untrained):  fra
# output (trained):
#
#
# input:               nu kan man endelig få øve <extra_id_0>lokalets<extra_id_1> hemmelighed er at se på en scenen
# expected output:
# output (untrained):  lokalets
# output (trained):    lokalets
#
#
# input:               vælg <extra_id_0>auto<extra_id_1> korrektur i minu
# expected output:     autokorrektur
# output (untrained):  auto
# output (trained):    autokorrektur
#
#
# input:               opret dokument oversigt på et drev <extra_id_0>se<extra_id_1>
# expected output:     c
# output (untrained):  se
# output (trained):
#
#
# input:               de unge der takker <extra_id_0>hver<extra_id_1> familiens indsats har fået job og indflydelse skal give familien noget igen
# expected output:     være
# output (untrained):  hver
# output (trained):    hvert familiens
#
#
# input:               <extra_id_0>benet<extra_id_1> fed skrift i dokumentet
# expected output:     benyt
# output (untrained):  benet
# output (trained):    benyt
#
#
# input:               giv denne <extra_id_0>med<extra_id_1> lav prioritet
# expected output:     email
# output (untrained):  med
# output (trained):
#
#
# input:               skulle man blive <extra_id_0>med<extra_id_1> af den påtrængende virksom i nutid kan man oppe på sin udkigspost vende sig mod øst
# expected output:     mæt
# output (untrained):  med
# output (trained):    med
#
#
# input:               <extra_id_0>definerer<extra_id_1> årsagen til de hyppigt forekommende fejl
# expected output:     definer
# output (untrained):  definerer
# output (trained):    definer
#
#
# input:               konklusionen må være at hvis man skal finde de lydløse så skal man gå efter strøm <extra_id_0>besparelsen<extra_id_1>
# expected output:
# output (untrained):  besparelsen
# output (trained):
#
#
# input:               treogtredive tusind seks hundrede og <extra_id_0>otte<extra_id_1> halvtreds
# expected output:     otteoghalvtreds
# output (untrained):  otte
# output (trained):    otteoghalvtreds
#
#
# input:               det ligner ikke ret meget men det sikrer at det nederste er rosen ikke <extra_id_0>tørre<extra_id_1> ud i hårde frost perioder
# expected output:     tørrer
# output (untrained):  tørre
# output (trained):    tørre
#
#
# input:               seks nul seks ni toogtyve syv hundrede og ni <extra_id_0>ofir<extra_id_1>
# expected output:
# output (untrained):  ofir
# output (trained):
#
#
# input:               her snegler bilerne sig af sted på grus vejene for at få glimt <extra_id_0>af<extra_id_1> ørne og glenter og det giver næsten altid bonus
# expected output:     at
# output (untrained):  af
# output (trained):    af
#
#
# input:               nu gider han ikke længere at <extra_id_0>have<extra_id_1> med musik at gøre overhovedet
# expected output:
# output (untrained):  have
# output (trained):
#
#
# input:               det svæver op i nattehimlen så man frygter at det <extra_id_0>her<extra_id_1> et øjeblik kunne den falde ned
# expected output:     hvert
# output (untrained):  her
# output (trained):
#
#
# input:               han foretog et kæmpe <extra_id_0>sving<extra_id_1> men bankede benene i måtterne fordi han ikke inden øvelsen havde lagt disse ordentligt på plads
# expected output:
# output (untrained):  sving
# output (trained):
#
#
# input:               for ikke så mange år siden var den danske befolkning livlig optaget af hvilket tøj i <extra_id_0>folketingskandidaterne<extra_id_1> i klædt sig under en valgkamp
# expected output:
# output (untrained):  folketingskandidate
# output (trained):    folketingskandidate
#
#
# input:               <extra_id_0>vi<extra_id_1> forslaget os til livs eller underminere vores position
# expected output:     vil
# output (untrained):  vi
# output (trained):    vi
#
#
# input:               der skal også være tid til sneboldkamp <extra_id_0>hule<extra_id_1> bygning indendørs lege og spil
# expected output:
# output (untrained):  hule
# output (trained):
#
#
# input:               tre otte seks nul tyve tre hundrede og otto <extra_id_0>halvfems<extra_id_1>
# expected output:
# output (untrained):  halvfems
# output (trained):
#
#
# input:               det er for de arbejdere <extra_id_0>og<extra_id_1> ofte møder allerede klokken syv altså en time før de fleste skoler begynder
# expected output:     ofte
# output (untrained):  og
# output (trained):    ofte
#
#
# input:               men det er før set komma at professionelle komma der skal have en amatør marked komma ikke ligefrem af <extra_id_0>over<extra_id_1> motiveret punktum
# expected output:
# output (untrained):  over
# output (trained):    overmotiverede
#
#
# input:               nul seks to ni fire <extra_id_0>og<extra_id_1> halvfems ni hundrede og sytten
# expected output:
# output (untrained):  og
# output (trained):
#
#
# input:               de unge der takker hver familiens indsats har fået et <extra_id_0>job<extra_id_1> og indflydelse skal give familien noget igen
# expected output:
# output (untrained):  job
# output (trained):
#
#
# input:               så tager han sig <extra_id_0>vældig<extra_id_1> sammen
# expected output:     vældigt
# output (untrained):  vældig
# output (trained):    vældig
#
#
# input:               <extra_id_0>åben<extra_id_1> ny mappe favoritter
# expected output:     åbn
# output (untrained):  åben
# output (trained):    åbn
#
#
# input:               det bliver dem der kommer til at styre information og debat i morgen <extra_id_0>dagens<extra_id_1> samfund
# expected output:
# output (untrained):  dagens
# output (trained):
#
#
# input:               her kan strømmen let gå komma og så er det rart at have <extra_id_0>et<extra_id_1> lys i mørket punktum
# expected output:     lidt
# output (untrained):  et
# output (trained):    lys
#
#
# input:               kunstnerne stræber ofte efter en nærmest <extra_id_0>og<extra_id_1> for bygningsværker og lignende til at svæve i luften punktum
# expected output:     at
# output (untrained):  og
# output (trained):    og
#
#
# input:               derfor er dommer kursen også i år blevet skærpet og ling <extra_id_0>terne<extra_id_1> medvirker til at observere ulovlighederne
# expected output:
# output (untrained):
# output (trained):
#
#
# input:               jeg hørte i en læge udsendelse og det er godt at give øjnene <extra_id_0>i<extra_id_1> en dråbe amerikansk olie to gange dagligt hvis det føltes generende tørre
# expected output:     en
# output (untrained):  i
# output (trained):
#
#
# input:               gem den markerede fil på <extra_id_0>atriet<extra_id_1>
# expected output:     adrevet
# output (untrained):  atriet
# output (trained):    at at riet
#
#
# input:               alle deres folk der havde været på ulykkesstedet inden for den radioaktive <extra_id_0>zonen<extra_id_1> blev målt når de vendte tilbage
# expected output:     zone
# output (untrained):  zonen
# output (trained):    zone
#
#
# input:               de enkelte udgivelser fra forskellige lande er en slags musik <extra_id_0>arkæologi<extra_id_1> som dokumenterer oprindelige traditioner før de moderne tider satte ind
# expected output:
# output (untrained):  arkæologi
# output (trained):
#
#
# input:               cirka tre minutter tog det generalsekretæren <extra_id_0>og<extra_id_1> hammer rør og led sammen hvorefter hans bidrag til den tretten meter høje gitter konstruktion blev sat på plads
# expected output:     at
# output (untrained):  og
# output (trained):    og
#
#
# input:               hvis autoritet <extra_id_0>er<extra_id_1> dette dokument
# expected output:     af
# output (untrained):  er
# output (trained):    er
#
#
# input:               øen får en glas bindestreg og <extra_id_0>keramik<extra_id_1> skole på internationalt niveau næste år punktum
# expected output:     keramikskole
# output (untrained):  keramik
# output (trained):    keramikskole
#
#
# input:               han mener at kravet om binding af bistanden kan betyde at u <extra_id_0>landene<extra_id_1> får mindre valuta for pengene
# expected output:
# output (untrained):  landene
# output (trained):
#
#
# input:               jeg har fået besked fra socialdirektoratet om at indrapportere navne og cpr <extra_id_0>bindestreg<extra_id_1> numre på dem komma der ikke betaler punktum
# expected output:
# output (untrained):  bindestreg
# output (trained):
#
#
# input:               stykket blander teater dans musik og <extra_id_0>video<extra_id_1> effekter og det handler om et par og deres liv
# expected output:     videoeffekter
# output (untrained):  video
# output (trained):    videoeffekter
#
#
# input:               laurids <extra_id_0>nørregaard<extra_id_1>
# expected output:     nørgård
# output (untrained):  Nørregaard
# output (trained):    nørregaard
#
#
# input:               jeg mener at vi har pligt til at stoppe <extra_id_0>denne<extra_id_1> konflikt
# expected output:     den
# output (untrained):  denne
# output (trained):    denne
#
#
# input:               der skal også være tid til sneboldkamp hule bygning inden <extra_id_0>deres<extra_id_1> lege og spil
# expected output:     hulebygning
# output (untrained):  deres
# output (trained):
#
#
# input:               resultatet af lægernes forsøg på at føre det <extra_id_0>er<extra_id_1> hver i tidsskrift over i den digitale tidsalder er flot
# expected output:     ærværdige
# output (untrained):  er
# output (trained):    ærhver
#
#
# input:               i først komme i weekenden kan man opleve de islandske hestes fem <extra_id_0>gange<extra_id_1> er der her under tønden som de racerene islandske heste er ene om at kunne
# expected output:     gangarter
# output (untrained):  gange
# output (trained):    gange
#
#
# input:               tilføj auto <extra_id_0>resume<extra_id_1> for alle celler
# expected output:
# output (untrained):  resume
# output (trained):
#
#
# input:               og sådan en lyseblå stol hvor skindet sidder som et løst betræk er milevidt fra de læder <extra_id_0>møbler<extra_id_1> der var statussymbol i tresserne
# expected output:
# output (untrained):  møbler
# output (trained):
#
#
# input:               nitten tusind et hundrede og <extra_id_0>otte<extra_id_1> halvfems
# expected output:     otteoghalvfems
# output (untrained):  otte
# output (trained):    otteoghalvfems
#
#
# input:               afbrød denne funktion og <extra_id_0>læst<extra_id_1> nederste linie
# expected output:     læs
# output (untrained):  læst
# output (trained):    læs
